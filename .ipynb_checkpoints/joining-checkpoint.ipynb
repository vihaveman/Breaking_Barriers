# %%
# !pip install pandas geopandas
# Out:
# Requirement already satisfied: pandas in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: geopandas in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: shapely>=1.6 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.4)
# Requirement already satisfied: fiona>=1.8 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: six in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: click~=8.0 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: importlib-metadata in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (4.11.3)
# Requirement already satisfied: certifi in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Requirement already satisfied: cligj>=0.5 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.8.0)

# %%
import pandas as pd
import geopandas as gpd

# %%
geojson_data = gpd.read_file('countries.geojson')

# %%
df = pd.DataFrame(geojson_data)
df.shape
df
# Out:
#             ADMIN ISO_A3 ISO_A2  \
# 0           Aruba    ABW     AW
# 1     Afghanistan    AFG     AF
# 2          Angola    AGO     AO
# 3        Anguilla    AIA     AI
# 4         Albania    ALB     AL
# ..            ...    ...    ...
# 250         Samoa    WSM     WS
# 251         Yemen    YEM     YE
# 252  South Africa    ZAF     ZA
# 253        Zambia    ZMB     ZM
# 254      Zimbabwe    ZWE     ZW
#
#                                               geometry
# 0    MULTIPOLYGON (((-69.99694 12.57758, -69.93639 ...
# 1    MULTIPOLYGON (((71.04980 38.40866, 71.05714 38...
# 2    MULTIPOLYGON (((11.73752 -16.69258, 11.73851 -...
# 3    MULTIPOLYGON (((-63.03767 18.21296, -63.09952 ...
# 4    MULTIPOLYGON (((19.74777 42.57890, 19.74601 42...
# ..                                                 ...
# 250  MULTIPOLYGON (((-171.57002 -13.93816, -171.564...
# 251  MULTIPOLYGON (((53.30824 12.11839, 53.31027 12...
# 252  MULTIPOLYGON (((37.86378 -46.94085, 37.83644 -...
# 253  MULTIPOLYGON (((31.11984 -8.61663, 31.14102 -8...
# 254  MULTIPOLYGON (((30.01065 -15.64623, 30.05024 -...
#
# [255 rows x 4 columns]

# %%
# Create a new DataFrame tech_clusters_df_rev as a copy of tech_clusters_df
tech_data=pd.read_csv('tech_data.csv')
tech_clusters_df_rev = tech_data.copy()
tech_clusters_df_rev.shape
# Out:
# (264, 7)

# %%
# Rename the 'Countries' column to 'ADMIN' in tech_clusters_df_rev DataFrame
tech_clusters_df_rev.rename(columns={'Countries': 'ADMIN'}, inplace=True)
tech_clusters_df_rev.shape
# Out:
# (264, 7)

# %%
# Perform the join using the 'ADMIN' column with an outer join
merged_df = pd.merge(df, tech_clusters_df_rev, on='ADMIN', how='left')
merged_df.shape
# Out:
# (255, 10)

# %%
merged_df.sample(50)
# Out:
#                                 ADMIN ISO_A3 ISO_A2  \
# 7                United Arab Emirates    ARE     AE
# 247                           Vanuatu    VUT     VU
# 184                       North Korea    PRK     KP
# 120                             Kenya    KEN     KE
# 39                             Canada    CAN     CA
# 74                            Finland    FIN     FI
# 170                             Nepal    NPL     NP
# 145                          Maldives    MDV     MV
# 166                         Nicaragua    NIC     NI
# 86                             Guinea    GIN     GN
# 112                             Italy    ITA     IT
# 126                            Kosovo    -99      -
# 47   Democratic Republic of the Congo    COD     CD
# 6                             Andorra    AND     AD
# 100                             Haiti    HTI     HT
# 218                        Seychelles    SYC     SC
# 208                           Somalia    SOM     SO
# 235                           Ukraine    UKR     UA
# 81                     United Kingdom    GBR     GB
# 243                         Venezuela    VEN     VE
# 135                           Lesotho    LSO     LS
# 149                              Mali    MLI     ML
# 242  Saint Vincent and the Grenadines    VCT     VC
# 147                  Marshall Islands    MHL     MH
# 132                       Saint Lucia    LCA     LC
# 107                           Ireland    IRL     IE
# 61                            Germany    DEU     DE
# 187                         Palestine    PSE     PS
# 199                   Serranilla Bank    -99      -
# 16                            Austria    AUT     AT
# 63                           Dominica    DMA     DM
# 27       Bajo Nuevo Bank (Petrel Is.)    -99     UM
# 18                            Burundi    BDI     BI
# 210                Republic of Serbia    SRB     RS
# 25                        The Bahamas    BHS     BS
# 88                      Guinea Bissau    GNB     GW
# 155                        Mozambique    MOZ     MZ
# 140                      Saint Martin    MAF     MF
# 119                        Kazakhstan    KAZ     KZ
# 26             Bosnia and Herzegovina    BIH     BA
# 65                 Dominican Republic    DOM     DO
# 44                  Clipperton Island    -99      -
# 17                         Azerbaijan    AZE     AZ
# 87                             Gambia    GMB     GM
# 133                     Liechtenstein    LIE     LI
# 198                           Senegal    SEN     SN
# 43                        Ivory Coast    CIV     CI
# 40                        Switzerland    CHE     CH
# 0                               Aruba    ABW     AW
# 148                         Macedonia    MKD     MK
#
#                                               geometry       PC1       PC2  \
# 7    MULTIPOLYGON (((53.86305 24.23469, 53.88860 24...  1.785821 -1.250941
# 247  MULTIPOLYGON (((169.83815 -20.24863, 169.83009... -1.003535  1.469132
# 184  MULTIPOLYGON (((125.31275 37.74140, 125.29575 ...       NaN       NaN
# 120  MULTIPOLYGON (((41.16277 -2.09092, 41.15528 -2... -1.898368 -0.288739
# 39   MULTIPOLYGON (((-65.61059 43.42817, -65.62881 ...  4.592915 -1.440838
# 74   MULTIPOLYGON (((22.44370 59.85147, 22.42774 59...  3.272794 -1.153580
# 170  MULTIPOLYGON (((81.77902 30.35804, 81.80150 30... -1.862411 -0.445148
# 145  MULTIPOLYGON (((73.16310 -0.68182, 73.17254 -0... -1.110914 -0.660389
# 166  MULTIPOLYGON (((-83.72037 11.88369, -83.71984 ... -1.862767 -0.277179
# 86   MULTIPOLYGON (((-13.33861 12.63923, -13.33277 ... -2.771384  0.018426
# 112  MULTIPOLYGON (((12.62127 35.49234, 12.61109 35...  3.097372 -1.167301
# 126  MULTIPOLYGON (((20.86470 43.21734, 20.86160 43... -1.869823 -0.002109
# 47   MULTIPOLYGON (((12.99459 -5.86824, 12.96930 -5...       NaN       NaN
# 6    MULTIPOLYGON (((1.70701 42.50278, 1.69750 42.4...  1.074580 -1.177877
# 100  MULTIPOLYGON (((-73.69424 18.10688, -73.68786 ... -1.859976 -0.673952
# 218  MULTIPOLYGON (((46.50066 -9.74651, 46.49049 -9...  0.511778 -0.891973
# 208  MULTIPOLYGON (((50.79786 11.98912, 50.86706 11... -1.285963 -0.569086
# 235  MULTIPOLYGON (((29.80747 45.61433, 29.73097 45...  0.834982 -0.648900
# 81   MULTIPOLYGON (((-6.28751 49.91401, -6.29727 49...  4.261249 -1.011080
# 243  MULTIPOLYGON (((-61.39027 8.58058, -61.36986 8... -0.133607 -0.374484
# 135  MULTIPOLYGON (((28.98085 -28.90904, 28.99542 -... -1.805766  0.124563
# 149  MULTIPOLYGON (((-4.82123 24.99475, -4.74493 24... -1.114757 -0.327747
# 242  MULTIPOLYGON (((-61.43273 12.58784, -61.44323 ...       NaN       NaN
# 147  MULTIPOLYGON (((168.71681 4.57477, 168.68539 4... -0.059396  2.186213
# 132  MULTIPOLYGON (((-60.88679 14.01008, -60.88296 ...       NaN       NaN
# 107  MULTIPOLYGON (((-9.82409 51.63890, -9.81697 51...  3.762072 -0.522981
# 61   MULTIPOLYGON (((6.74220 53.57836, 6.74952 53.5...  4.352282 -0.752486
# 187  MULTIPOLYGON (((34.26440 31.22419, 34.24835 31...       NaN       NaN
# 199  MULTIPOLYGON (((-78.63707 15.86209, -78.64041 ...       NaN       NaN
# 16   MULTIPOLYGON (((15.16179 48.93722, 15.23807 48...  3.975645 -1.596855
# 63   MULTIPOLYGON (((-61.36286 15.20181, -61.37409 ...  1.727156 -1.054706
# 27   MULTIPOLYGON (((-79.98929 15.79495, -79.98782 ...       NaN       NaN
# 18   MULTIPOLYGON (((30.41507 -2.31309, 30.41848 -2... -2.904902 -0.449602
# 210  MULTIPOLYGON (((19.69009 46.16840, 19.71189 46...       NaN       NaN
# 25   MULTIPOLYGON (((-73.03393 21.15673, -73.09759 ...       NaN       NaN
# 88   MULTIPOLYGON (((-15.90160 11.14228, -15.89485 ...       NaN       NaN
# 155  MULTIPOLYGON (((32.97511 -26.00945, 32.96453 -... -2.563082  0.142983
# 140  MULTIPOLYGON (((-63.01757 18.03339, -63.08589 ...       NaN       NaN
# 119  MULTIPOLYGON (((50.65952 44.93895, 50.67799 44...  0.673375 -0.695288
# 26   MULTIPOLYGON (((16.94153 45.24122, 16.94732 45... -0.323130 -1.207303
# 65   MULTIPOLYGON (((-71.50739 17.55126, -71.52448 ... -0.546555 -0.542176
# 44   MULTIPOLYGON (((-109.21203 10.30268, -109.2103...       NaN       NaN
# 17   MULTIPOLYGON (((45.07500 39.74982, 45.14125 39... -0.100294 -0.487255
# 87   MULTIPOLYGON (((-14.74093 13.61545, -14.72858 ... -2.956570 -0.307949
# 133  MULTIPOLYGON (((9.58120 47.05687, 9.56064 47.0...  0.393603 -0.468436
# 198  MULTIPOLYGON (((-14.91250 16.64064, -14.88201 ... -1.926462  0.038247
# 43   MULTIPOLYGON (((-3.18497 5.13227, -3.16340 5.1...       NaN       NaN
# 40   MULTIPOLYGON (((8.61744 47.75732, 8.62984 47.7...  5.268910 -0.871871
# 0    MULTIPOLYGON (((-69.99694 12.57758, -69.93639 ...  1.886372 -1.033924
# 148  MULTIPOLYGON (((22.34502 42.31344, 22.44362 42...       NaN       NaN
#
#           PC3       PC4       PC5  TechCluster
# 7    0.769194  0.161986 -0.038151          3.0
# 247 -0.115685 -2.329922 -1.225112          1.0
# 184       NaN       NaN       NaN          NaN
# 120 -0.260745 -0.139125  0.193588          1.0
# 39  -0.183591 -0.442135  0.113601          0.0
# 74  -0.745697 -0.035010  0.788703          0.0
# 170  1.008359  0.596424 -0.987572          1.0
# 145  1.972351  0.960818 -0.950970          3.0
# 166  0.442867 -0.164875 -0.628749          1.0
# 86   0.054247 -0.451676  0.741071          1.0
# 112 -0.342794 -0.116951  0.663611          0.0
# 126  0.501025 -0.117998 -0.634123          1.0
# 47        NaN       NaN       NaN          NaN
# 6    1.885895  0.650032  0.003041          3.0
# 100  1.612448 -0.692222  0.458909          1.0
# 218  1.231929  0.266192  1.023126          3.0
# 208  0.066609 -0.323382  0.969328          1.0
# 235 -0.357165  0.638823 -0.023509          3.0
# 81  -0.766657 -0.335958 -0.223415          0.0
# 243 -0.223953 -0.842707 -0.327470          3.0
# 135  0.649866 -0.650703 -0.383631          1.0
# 149 -1.431413 -0.457862 -0.336989          1.0
# 242       NaN       NaN       NaN          NaN
# 147 -1.724838  0.108123 -1.162874          1.0
# 132       NaN       NaN       NaN          NaN
# 107 -1.668934  0.601595  1.028370          0.0
# 61  -1.576457 -0.228339  0.106204          0.0
# 187       NaN       NaN       NaN          NaN
# 199       NaN       NaN       NaN          NaN
# 16  -0.748224  0.360953  0.579407          0.0
# 63  -1.100258 -0.158642  0.252017          0.0
# 27        NaN       NaN       NaN          NaN
# 18   0.231490 -1.067586 -0.282941          1.0
# 210       NaN       NaN       NaN          NaN
# 25        NaN       NaN       NaN          NaN
# 88        NaN       NaN       NaN          NaN
# 155 -1.017543 -0.213486  0.651764          1.0
# 140       NaN       NaN       NaN          NaN
# 119  0.109506  1.186825  0.658046          3.0
# 26   1.533095  1.807891  0.010705          3.0
# 65  -0.219795  0.458625 -1.924058          3.0
# 44        NaN       NaN       NaN          NaN
# 17   0.196639  1.726948  0.505078          3.0
# 87   0.966743 -0.655255 -0.178978          1.0
# 133  1.045132  0.093343  0.324632          3.0
# 198 -0.291883 -0.902367 -0.719787          1.0
# 43        NaN       NaN       NaN          NaN
# 40  -2.004317 -0.957835  0.451809          0.0
# 0    0.521251 -0.163202  0.948541          0.0
# 148       NaN       NaN       NaN          NaN

# %%
# Replace NaN with the value 5 in the 'TechCluster' column
merged_df['TechCluster'] = merged_df['TechCluster'].fillna(2)

# %%
# Get the unique values in the 'TechCluster' column
unique_tech_clusters = merged_df['TechCluster'].unique()

# Print the unique values
print(unique_tech_clusters)
# Out:
# [0. 1. 2. 3.]

# %%
gdf = gpd.GeoDataFrame(merged_df, geometry='geometry')

# Save the GeoDataFrame as a GeoJSON file
output_file = 'output.geojson'  # Replace with the desired output file path
gdf.to_file(output_file, driver='GeoJSON')
# Out:
# /Users/zhibekabdyramanova/opt/anaconda3/lib/python3.9/site-packages/geopandas/io/file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
