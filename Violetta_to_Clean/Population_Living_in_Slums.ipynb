# %%
#Import Dependancies
import pandas as pd
import os

# %%
#Import File
livining_in_slums = 'Population_Living_in_Slums.csv'
livining_in_slums_df = pd.read_csv(livining_in_slums,  sep="\t")
livining_in_slums_df.head(10)
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2023-06-29",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Population living in slums (% of ...
# 3  Africa Eastern and Southern,"AFE","Population ...
# 4  Afghanistan,"AFG","Population living in slums ...
# 5  Africa Western and Central,"AFW","Population l...
# 6  Angola,"AGO","Population living in slums (% of...
# 7  Albania,"ALB","Population living in slums (% o...
# 8  Andorra,"AND","Population living in slums (% o...
# 9  Arab World,"ARB","Population living in slums (...

# %%
list(livining_in_slums_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = livining_in_slums_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
# Split columns
split_data = livining_in_slums_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
split_livining_in_slums_df = pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)


# Concatenate the remaining columns from original data
split_livining_in_slums_df = pd.concat([split_livining_in_slums_df, split_data.iloc[:, 4:]], axis=1)
split_livining_in_slums_df = split_livining_in_slums_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_livining_in_slums_df.head(10)
# Out:
#                   Country Name    Country Code  \
# 0                 Country Name  "Country Code"
# 1                        Aruba           "ABW"
# 2  Africa Eastern and Southern           "AFE"
# 3                  Afghanistan           "AFG"
# 4   Africa Western and Central           "AFW"
# 5                       Angola           "AGO"
# 6                      Albania           "ALB"
# 7                      Andorra           "AND"
# 8                   Arab World           "ARB"
# 9         United Arab Emirates           "ARE"
#
#                                       Indicator Name       Indicator Code  \
# 0                                   "Indicator Name"     "Indicator Code"
# 1  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# 2  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# 3  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# ...

# %%
# Assign row 0 as column names
split_livining_in_slums_df.columns = split_livining_in_slums_df.iloc[0]

# Remove any quotation marks from column names
split_livining_in_slums_df.columns = split_livining_in_slums_df.columns.str.replace('"', '')

# Drop row 0 from the DataFrame
split_livining_in_slums_df = split_livining_in_slums_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_livining_in_slums_df.head(10)
# Out:
# 0                 Country Name Country Code  \
# 0                        Aruba        "ABW"
# 1  Africa Eastern and Southern        "AFE"
# 2                  Afghanistan        "AFG"
# 3   Africa Western and Central        "AFW"
# 4                       Angola        "AGO"
# 5                      Albania        "ALB"
# 6                      Andorra        "AND"
# 7                   Arab World        "ARB"
# 8         United Arab Emirates        "ARE"
# 9                    Argentina        "ARG"
#
# 0                                     Indicator Name       Indicator Code  \
# 0  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# 1  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# 2  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# 3  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# 4  "Population living in slums (% of urban popula...  "EN.POP.SLUM.UR.ZS"
# ...

# %%
#Filtered columns for desired years
years_columns = [str(year) for year in range(2010, 2021)]

# Select the desired columns
selected_columns = ['Country Name', 'Country Code'] + years_columns

# Create the new DataFrame
selected_columns = split_livining_in_slums_df[selected_columns]

cleaned_livining_in_slums_df = selected_columns

cleaned_livining_in_slums_df.head(10)
# Out:
# 0                 Country Name Country Code                2010 2011  \
# 0                        Aruba        "ABW"                  ""   ""
# 1  Africa Eastern and Southern        "AFE"  "57.6771929585988"   ""
# 2                  Afghanistan        "AFG"          "64.80761"   ""
# 3   Africa Western and Central        "AFW"  "58.9139334015265"   ""
# 4                       Angola        "AGO"          "38.05496"   ""
# 5                      Albania        "ALB"              "15.4"   ""
# 6                      Andorra        "AND"                  ""   ""
# 7                   Arab World        "ARB"  "31.8523767002419"   ""
# 8         United Arab Emirates        "ARE"                  ""   ""
# 9                    Argentina        "ARG"          "16.66365"   ""
#
# 0                2012 2013                2014 2015                2016 2017  \
# 0                  ""   ""                  ""   ""                  ""   ""
# ...

# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_livining_in_slums_df = cleaned_livining_in_slums_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_livining_in_slums_df.columns[2:13]:
    cleaned_livining_in_slums_df[column] = pd.to_numeric(cleaned_livining_in_slums_df[column], errors='coerce')

# Display the updated DataFrame
cleaned_livining_in_slums_df.head()
# Out:
# 0                 Country Name Country Code       2010  2011       2012  2013  \
# 0                        Aruba          ABW        NaN   NaN        NaN   NaN
# 1  Africa Eastern and Southern          AFE  57.677193   NaN  56.906810   NaN
# 2                  Afghanistan          AFG  64.807610   NaN  67.247950   NaN
# 3   Africa Western and Central          AFW  58.913933   NaN  56.315351   NaN
# 4                       Angola          AGO  38.054960   NaN  44.186480   NaN
#
# 0       2014  2015       2016  2017       2018  2019       2020
# 0        NaN   NaN        NaN   NaN        NaN   NaN        NaN
# 1  56.138957   NaN  55.348711   NaN  54.672940   NaN  54.386351
# 2  69.688290   NaN  72.128630   NaN  73.300000   NaN  73.300000
# 3  53.714597   NaN  51.120997   NaN  48.698234   NaN  46.257180
# 4  50.318010   NaN  56.449530   NaN  62.581050   NaN  62.600000

# %%
# Replace the NaN values with 0
cleaned_livining_in_slums_df.fillna(0, inplace=True)

cleaned_livining_in_slums_df.head(10)
# Out:
# 0                 Country Name Country Code       2010  2011       2012  2013  \
# 0                        Aruba          ABW   0.000000   0.0   0.000000   0.0
# 1  Africa Eastern and Southern          AFE  57.677193   0.0  56.906810   0.0
# 2                  Afghanistan          AFG  64.807610   0.0  67.247950   0.0
# 3   Africa Western and Central          AFW  58.913933   0.0  56.315351   0.0
# 4                       Angola          AGO  38.054960   0.0  44.186480   0.0
# 5                      Albania          ALB  15.400000   0.0  12.900000   0.0
# 6                      Andorra          AND   0.000000   0.0   0.000000   0.0
# 7                   Arab World          ARB  31.852377   0.0  28.653925   0.0
# 8         United Arab Emirates          ARE   0.000000   0.0   0.000000   0.0
# 9                    Argentina          ARG  16.663650   0.0  15.938010   0.0
#
# 0       2014  2015       2016  2017       2018  2019       2020
# ...

# %%
# Calculate the average for each country
average_by_country = cleaned_livining_in_slums_df.groupby('Country Code').apply(lambda group: group.drop(columns=['Country Name', 'Country Code']).mean(skipna=True, axis=1))

# Replace all 0.0 values with the corresponding country average
for col in cleaned_livining_in_slums_df.columns[2:]:
    cleaned_livining_in_slums_df[col] = cleaned_livining_in_slums_df.apply(lambda row: average_by_country[row['Country Code']][row.name] if row[col] == 0.0 else row[col], axis=1)

cleaned_livining_in_slums_df.head(10)
# Out:
# 0                 Country Name Country Code       2010       2011       2012  \
# 0                        Aruba          ABW   0.000000   0.000000   0.000000
# 1  Africa Eastern and Southern          AFE  57.677193  30.466451  56.906810
# 2                  Afghanistan          AFG  64.807610  38.224771  67.247950
# 3   Africa Western and Central          AFW  58.913933  28.638208  56.315351
# 4                       Angola          AGO  38.054960  28.562730  44.186480
# 5                      Albania          ALB  15.400000   4.954545  12.900000
# 6                      Andorra          AND   0.000000   0.000000   0.000000
# 7                   Arab World          ARB  31.852377  12.147964  28.653925
# 8         United Arab Emirates          ARE   0.000000   0.000000   0.000000
# 9                    Argentina          ARG  16.663650   2.963787  15.938010
#
# 0       2013       2014       2015       2016       2017       2018  \
# ...

# %%
 # Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_livining_in_slums_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Population Living In Slums")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year", "Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year  Population Living In Slums
# 0                  Afghanistan          AFG  2010                       64.81
# 1  Africa Eastern and Southern          AFE  2010                       57.68
# 2   Africa Western and Central          AFW  2010                       58.91
# 3                      Albania          ALB  2010                       15.40
# 4                      Algeria          DZA  2010                       30.80

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/Population_Living_in_Slums.csv', index=False)
