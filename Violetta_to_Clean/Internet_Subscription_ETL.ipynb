# %%
import pandas as pd
import os

# %%
in_subs = "Internet_Subscription_Per100.csv"
in_subs_df = pd.read_csv(in_subs, sep="\t")
in_subs_df.head(10)
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2023-06-29",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Fixed broadband subscriptions (pe...
# 3  Africa Eastern and Southern,"AFE","Fixed broad...
# 4  Afghanistan,"AFG","Fixed broadband subscriptio...
# 5  Africa Western and Central,"AFW","Fixed broadb...
# 6  Angola,"AGO","Fixed broadband subscriptions (p...
# 7  Albania,"ALB","Fixed broadband subscriptions (...
# 8  Andorra,"AND","Fixed broadband subscriptions (...
# 9  Arab World,"ARB","Fixed broadband subscription...

# %%
list(in_subs_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = in_subs_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
split_data = in_subs_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
cleaned_in_subs_df= pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)

# Concatenate the remaining columns from split_data to cleaned_atm_df
cleaned_in_subs_df = pd.concat([cleaned_in_subs_df, split_data.iloc[:, 4:]], axis=1)
cleaned_in_subs_df = cleaned_in_subs_df.drop(index=0).reset_index(drop=True)
# Display the cleaned DataFrame
cleaned_in_subs_df.head(5)
# Out:
#                   Country Name    Country Code  \
# 0                 Country Name  "Country Code"
# 1                        Aruba           "ABW"
# 2  Africa Eastern and Southern           "AFE"
# 3                  Afghanistan           "AFG"
# 4   Africa Western and Central           "AFW"
#
#                                      Indicator Name    Indicator Code       4  \
# 0                                  "Indicator Name"  "Indicator Code"  "1960"
# 1  "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"      ""
# 2  "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"      ""
# 3  "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"      ""
# 4  "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"      ""
#
#         5       6       7       8       9  ...                   59  \
# 0  "1961"  "1962"  "1963"  "1964"  "1965"  ...               "2015"
# 1      ""      ""      ""      ""      ""  ...        "18.22419598"
# ...

# %%
# Assign row 0 as column names
cleaned_in_subs_df.columns = cleaned_in_subs_df.iloc[0]

# Remove any quotation marks from column names
cleaned_in_subs_df.columns = cleaned_in_subs_df.columns.str.replace('"', '')  # Remove any quotation marks from column names

# Drop row 0 from the DataFrame
cleaned_in_subs_df = cleaned_in_subs_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
cleaned_in_subs_df.sample(5)
# Out:
# 0   Country Name Country Code  \
# 158         Mali        "MLI"
# 2    Afghanistan        "AFG"
# 75       Finland        "FIN"
# 35        Canada        "CAN"
# 92     Guatemala        "GTM"
#
# 0                                      Indicator Name    Indicator Code 1960  \
# 158  "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"   ""
# 2    "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"   ""
# 75   "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"   ""
# 35   "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"   ""
# 92   "Fixed broadband subscriptions (per 100 people)"  "IT.NET.BBND.P2"   ""
#
# 0   1961 1962 1963 1964 1965  ...           2015           2016  \
# 158   ""   ""   ""   ""   ""  ...  "0.019317716"  "0.114673147"
# 2     ""   ""   ""   ""   ""  ...  "0.020937089"  "0.025409826"
# 75    ""   ""   ""   ""   ""  ...  "31.57056871"  "31.15435436"
# ...

# %%
#Filtered columns for desired years
years_columns = [str(year) for year in range(2010, 2021)]

# Select the desired columns
selected_columns = ['Country Name', 'Country Code'] + years_columns

# Create the new DataFrame
selected_columns = cleaned_in_subs_df[selected_columns]

cleaned_in_subs_df = selected_columns

cleaned_in_subs_df.head(10)
# Out:
# 0                 Country Name Country Code                 2010  \
# 0                        Aruba        "ABW"        "19.15150186"
# 1  Africa Eastern and Southern        "AFE"  "0.196025141368356"
# 2                  Afghanistan        "AFG"        "0.005321098"
# 3   Africa Western and Central        "AFW"  "0.105775943595984"
# 4                       Angola        "AGO"        "0.064200827"
# 5                      Albania        "ALB"        "3.622537242"
# 6                      Andorra        "AND"        "34.25942756"
# 7                   Arab World        "ARB"   "2.04323473083935"
# 8         United Arab Emirates        "ARE"         "9.27657679"
# 9                    Argentina        "ARG"        "9.801036362"
#
# 0                2011                 2012                 2013  \
# 0                  ""                   ""        "18.66251944"
# 1  "0.29238007125147"  "0.351953126198483"  "0.452910908034707"
# ...

# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_in_subs_df = cleaned_in_subs_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_in_subs_df.columns[2:13]:
    cleaned_in_subs_df[column] = pd.to_numeric(cleaned_in_subs_df[column], errors='coerce')
    
# Display the updated DataFrame
cleaned_in_subs_df.head()
# Out:
# 0                 Country Name Country Code       2010     2011      2012  \
# 0                        Aruba          ABW  19.151502      NaN       NaN
# 1  Africa Eastern and Southern          AFE   0.196025  0.29238  0.351953
# 2                  Afghanistan          AFG   0.005321      NaN  0.004923
# 3   Africa Western and Central          AFW   0.105776      NaN  0.108366
# 4                       Angola          AGO   0.064201  0.06520  0.081435
#
# 0       2013       2014       2015      2016      2017      2018       2019  \
# 0  18.662519  18.533892  18.224196       NaN       NaN       NaN  17.850097
# 1   0.452911   0.535180   0.514451  0.507695  0.539088  0.691819   0.620279
# 2   0.004756   0.004585   0.020937  0.025410  0.025761  0.043610   0.052113
# 3   0.106400   0.132960   0.142783  0.238596  0.234462  0.269760   0.269671
# 4   0.085218   0.323463   0.545977  0.290601  0.320832  0.350331   0.368021
#
# 0       2020
# 0  17.826148
# 1   0.730465
# 2   0.068177
# ...

# %%
# Replace the NaN values with 0
cleaned_in_subs_df.fillna(0, inplace=True)

cleaned_in_subs_df.head(10)
# Out:
# 0                 Country Name Country Code       2010       2011       2012  \
# 0                        Aruba          ABW  19.151502   0.000000   0.000000
# 1  Africa Eastern and Southern          AFE   0.196025   0.292380   0.351953
# 2                  Afghanistan          AFG   0.005321   0.000000   0.004923
# 3   Africa Western and Central          AFW   0.105776   0.000000   0.108366
# 4                       Angola          AGO   0.064201   0.065200   0.081435
# 5                      Albania          ALB   3.622537   4.420038   5.535177
# 6                      Andorra          AND  34.259428  36.508049  37.887963
# 7                   Arab World          ARB   2.043235   2.613481   2.978249
# 8         United Arab Emirates          ARE   9.276577  10.110172  11.021250
# 9                    Argentina          ARG   9.801036  11.011420  12.272450
#
# 0       2013       2014       2015       2016       2017       2018  \
# ...

# %%
cleaned_in_subs_df

# Calculate the average for each country
average_by_country = cleaned_in_subs_df.groupby('Country Code').apply(lambda group: group.drop(columns=['Country Name', 'Country Code']).mean(skipna=True, axis=1))

# Replace all 0.0 values with the corresponding country average
for col in cleaned_in_subs_df.columns[2:]:
    cleaned_in_subs_df[col] = cleaned_in_subs_df.apply(lambda row: average_by_country[row['Country Code']][row.name] if row[col] == 0.0 else row[col], axis=1)

cleaned_in_subs_df.head(10)
# Out:
# 0                 Country Name Country Code       2010       2011       2012  \
# 0                        Aruba          ABW  19.151502  10.022578  10.022578
# 1  Africa Eastern and Southern          AFE   0.196025   0.292380   0.351953
# 2                  Afghanistan          AFG   0.005321   0.023236   0.004923
# 3   Africa Western and Central          AFW   0.105776   0.181564   0.108366
# 4                       Angola          AGO   0.064201   0.065200   0.081435
# 5                      Albania          ALB   3.622537   4.420038   5.535177
# 6                      Andorra          AND  34.259428  36.508049  37.887963
# 7                   Arab World          ARB   2.043235   2.613481   2.978249
# 8         United Arab Emirates          ARE   9.276577  10.110172  11.021250
# 9                    Argentina          ARG   9.801036  11.011420  12.272450
#
# 0       2013       2014       2015       2016       2017       2018  \
# ...

# %%
# Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_in_subs_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Internet Subscription Per 100")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year", "Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year  \
# 0                  Afghanistan          AFG  2010
# 1  Africa Eastern and Southern          AFE  2010
# 2   Africa Western and Central          AFW  2010
# 3                      Albania          ALB  2010
# 4                      Algeria          DZA  2010
#
#    Internet Subscription Per 100
# 0                           0.01
# 1                           0.20
# 2                           0.11
# 3                           3.62
# 4                           2.51

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/Internet_Sbcription.csv', index=False)
