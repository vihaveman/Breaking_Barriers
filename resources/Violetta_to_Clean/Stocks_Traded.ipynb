# %%
#Import Dependancies
import pandas as pd
import os

# %%
#Import File
stocks = 'Stocks_Traded.csv'
stocks_df = pd.read_csv(stocks,  sep="\t")
stocks_df.head(10)
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2023-06-29",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Stocks traded, total value (% of ...
# 3  Africa Eastern and Southern,"AFE","Stocks trad...
# 4  Afghanistan,"AFG","Stocks traded, total value ...
# 5  Africa Western and Central,"AFW","Stocks trade...
# 6  Angola,"AGO","Stocks traded, total value (% of...
# 7  Albania,"ALB","Stocks traded, total value (% o...
# 8  Andorra,"AND","Stocks traded, total value (% o...
# 9  Arab World,"ARB","Stocks traded, total value (...

# %%
list(stocks_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = stocks_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
# Split columns
split_data = stocks_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
split_stocks_df = pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)


# Concatenate the remaining columns from original data
split_stocks_df = pd.concat([split_stocks_df, split_data.iloc[:, 4:]], axis=1)
split_stocks_df = split_stocks_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_stocks_df.head(10)
# Out:
#                   Country Name    Country Code    Indicator Name  \
# 0                 Country Name  "Country Code"  "Indicator Name"
# 1                        Aruba           "ABW"    "Stocks traded
# 2  Africa Eastern and Southern           "AFE"    "Stocks traded
# 3                  Afghanistan           "AFG"    "Stocks traded
# 4   Africa Western and Central           "AFW"    "Stocks traded
# 5                       Angola           "AGO"    "Stocks traded
# 6                      Albania           "ALB"    "Stocks traded
# 7                      Andorra           "AND"    "Stocks traded
# 8                   Arab World           "ARB"    "Stocks traded
# 9         United Arab Emirates           "ARE"    "Stocks traded
#
#              Indicator Code                    4       5       6       7  \
# 0          "Indicator Code"               "1960"  "1961"  "1962"  "1963"
# 1   total value (% of GDP)"  "CM.MKT.TRAD.GD.ZS"      ""      ""      ""
# ...

# %%
# Assign row 0 as column names
split_stocks_df.columns = split_stocks_df.iloc[0]

# Remove any quotation marks from column names
split_stocks_df.columns = split_stocks_df.columns.str.replace('"', '')

# Drop row 0 from the DataFrame
split_stocks_df = split_stocks_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_stocks_df.head(10)
# Out:
# 0                 Country Name Country Code  Indicator Name  \
# 0                        Aruba        "ABW"  "Stocks traded
# 1  Africa Eastern and Southern        "AFE"  "Stocks traded
# 2                  Afghanistan        "AFG"  "Stocks traded
# 3   Africa Western and Central        "AFW"  "Stocks traded
# 4                       Angola        "AGO"  "Stocks traded
# 5                      Albania        "ALB"  "Stocks traded
# 6                      Andorra        "AND"  "Stocks traded
# 7                   Arab World        "ARB"  "Stocks traded
# 8         United Arab Emirates        "ARE"  "Stocks traded
# 9                    Argentina        "ARG"  "Stocks traded
#
# 0            Indicator Code                 1960 1961 1962 1963 1964 1965  \
# 0   total value (% of GDP)"  "CM.MKT.TRAD.GD.ZS"   ""   ""   ""   ""   ""
# 1   total value (% of GDP)"  "CM.MKT.TRAD.GD.ZS"   ""   ""   ""   ""   ""
# 2   total value (% of GDP)"  "CM.MKT.TRAD.GD.ZS"   ""   ""   ""   ""   ""
# ...

# %%
#Filtered columns for desired years
years_columns = [str(year) for year in range(2010, 2021)]

# Select the desired columns
selected_columns = ['Country Name', 'Country Code'] + years_columns

# Create the new DataFrame
selected_columns = split_stocks_df[selected_columns]

cleaned_stocks_df = selected_columns

cleaned_stocks_df.head(10)
# Out:
# 0                 Country Name Country Code                 2010  \
# 0                        Aruba        "ABW"                   ""
# 1  Africa Eastern and Southern        "AFE"                   ""
# 2                  Afghanistan        "AFG"                   ""
# 3   Africa Western and Central        "AFW"   "1.34813544254563"
# 4                       Angola        "AGO"                   ""
# 5                      Albania        "ALB"                   ""
# 6                      Andorra        "AND"                   ""
# 7                   Arab World        "ARB"                   ""
# 8         United Arab Emirates        "ARE"   "25.9527767613405"
# 9                    Argentina        "ARG"  "0.453659663659484"
#
# 0                 2011                 2012                 2013  \
# 0                   ""                   ""                   ""
# 1                   ""                   ""                   ""
# ...

# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_stocks_df = cleaned_stocks_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_stocks_df.columns[2:13]:
    cleaned_stocks_df[column] = pd.to_numeric(cleaned_stocks_df[column], errors='coerce')

# Display the updated DataFrame
cleaned_stocks_df.head()
# Out:
# 0                 Country Name Country Code      2010      2011      2012  \
# 0                        Aruba          ABW       NaN       NaN       NaN
# 1  Africa Eastern and Southern          AFE       NaN       NaN       NaN
# 2                  Afghanistan          AFG       NaN       NaN       NaN
# 3   Africa Western and Central          AFW  1.348135  1.251708  0.864962
# 4                       Angola          AGO       NaN       NaN       NaN
#
# 0      2013      2014      2015      2016  2017  2018  2019  2020
# 0       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 1       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 2       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 3  0.797348  1.084889  0.887906  0.854934   NaN   NaN   NaN   NaN
# 4       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN

# %%
# Perform data interpolation on the numeric columns
cleaned_stocks_df = cleaned_stocks_df.interpolate(method='linear')
cleaned_stocks_df.head(50)
# Out:
# 0                     Country Name Country Code        2010        2011  \
# 0                            Aruba          ABW         NaN         NaN
# 1      Africa Eastern and Southern          AFE         NaN         NaN
# 2                      Afghanistan          AFG         NaN         NaN
# 3       Africa Western and Central          AFW    1.348135    1.251708
# 4                           Angola          AGO    6.269064    2.914332
# 5                          Albania          ALB   11.189992    4.576956
# 6                          Andorra          AND   16.110920    6.239580
# 7                       Arab World          ARB   21.031848    7.902204
# 8             United Arab Emirates          ARE   25.952777    9.564828
# 9                        Argentina          ARG    0.453660    0.600714
# 10                         Armenia          ARM   22.994082   25.075456
# 11                  American Samoa          ASM   45.534504   49.550198
# ...

# %%
# Calculate the average for each country
average_by_country = cleaned_stocks_df.groupby('Country Code').apply(lambda group: group.drop(columns=['Country Name', 'Country Code']).mean(skipna=True, axis=1))

# Replace all 0.0 values with the corresponding country average
for col in cleaned_stocks_df.columns[2:]:
    cleaned_stocks_df[col] =cleaned_stocks_df.apply(lambda row: average_by_country[row['Country Code']][row.name] if row[col] == 0.0 else row[col], axis=1)

cleaned_stocks_df.head(10)
# Out:
# 0                 Country Name Country Code       2010       2011       2012  \
# 0                        Aruba          ABW   0.000000   0.000000   0.000000
# 1  Africa Eastern and Southern          AFE   0.000000   0.000000   0.000000
# 2                  Afghanistan          AFG   0.000000   0.000000   0.000000
# 3   Africa Western and Central          AFW   1.348135   1.251708   0.864962
# 4                       Angola          AGO   0.000000   0.000000   0.000000
# 5                      Albania          ALB   0.000000   0.000000   0.000000
# 6                      Andorra          AND   0.000000   0.000000   0.000000
# 7                   Arab World          ARB  16.389889  16.389889  19.645323
# 8         United Arab Emirates          ARE  25.952777   9.564828   4.278820
# 9                    Argentina          ARG   0.453660   0.600714   0.462939
#
# 0       2013       2014       2015       2016       2017       2018  \
# ...

# %%
# Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_stocks_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Stock Traded $B")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year","Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year  Stock Traded $B
# 0                  Afghanistan          AFG  2010             0.00
# 1  Africa Eastern and Southern          AFE  2010             0.00
# 2   Africa Western and Central          AFW  2010             1.35
# 3                      Albania          ALB  2010             0.00
# 4                      Algeria          DZA  2010             0.00

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/Stock_Traded.csv', index=False)
