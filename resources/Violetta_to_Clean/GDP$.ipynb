# %%
import pandas as pd
import os

# %%
gdp = "GDP $.csv"
gdp_df = pd.read_csv(gdp, sep="\t")
gdp_df.head(10)
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2023-07-25",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","GDP, PPP (current international $...
# 3  Africa Eastern and Southern,"AFE","GDP, PPP (c...
# 4  Afghanistan,"AFG","GDP, PPP (current internati...
# 5  Africa Western and Central,"AFW","GDP, PPP (cu...
# 6  Angola,"AGO","GDP, PPP (current international ...
# 7  Albania,"ALB","GDP, PPP (current international...
# 8  Andorra,"AND","GDP, PPP (current international...
# 9  Arab World,"ARB","GDP, PPP (current internatio...

# %%
list(gdp_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = gdp_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
split_data = gdp_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
cleaned_gdp_df = pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)

# Concatenate the remaining columns from split_data to cleaned_atm_df
cleaned_gdp_df = pd.concat([cleaned_gdp_df, split_data.iloc[:, 4:]], axis=1)
cleaned_gdp_df = cleaned_gdp_df.drop(index=0).reset_index(drop=True)
# Display the cleaned DataFrame
cleaned_gdp_df.head(5)
# Out:
#                   Country Name    Country Code    Indicator Name  \
# 0                 Country Name  "Country Code"  "Indicator Name"
# 1                        Aruba           "ABW"              "GDP
# 2  Africa Eastern and Southern           "AFE"              "GDP
# 3                  Afghanistan           "AFG"              "GDP
# 4   Africa Western and Central           "AFW"              "GDP
#
#                     Indicator Code                    4       5       6  \
# 0                 "Indicator Code"               "1960"  "1961"  "1962"
# 1   PPP (current international $)"  "NY.GDP.MKTP.PP.CD"      ""      ""
# 2   PPP (current international $)"  "NY.GDP.MKTP.PP.CD"      ""      ""
# 3   PPP (current international $)"  "NY.GDP.MKTP.PP.CD"      ""      ""
# 4   PPP (current international $)"  "NY.GDP.MKTP.PP.CD"      ""      ""
#
#         7       8       9  ...                  59                  60  \
# ...

# %%
# Assign row 0 as column names
cleaned_gdp_df.columns = cleaned_gdp_df.iloc[0]

# Remove any quotation marks from column names
cleaned_gdp_df.columns = cleaned_gdp_df.columns.str.replace('"', '')  

# Drop row 0 from the DataFrame
cleaned_gdp_df = cleaned_gdp_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
cleaned_gdp_df.sample(5)
# Out:
# 0         Country Name Country Code Indicator Name  \
# 88   Equatorial Guinea        "GNQ"           "GDP
# 190             Poland        "POL"           "GDP
# 39               Chile        "CHL"           "GDP
# 220           Suriname        "SUR"           "GDP
# 245             Tuvalu        "TUV"           "GDP
#
# 0                     Indicator Code                 1960 1961 1962 1963 1964  \
# 88    PPP (current international $)"  "NY.GDP.MKTP.PP.CD"   ""   ""   ""   ""
# 190   PPP (current international $)"  "NY.GDP.MKTP.PP.CD"   ""   ""   ""   ""
# 39    PPP (current international $)"  "NY.GDP.MKTP.PP.CD"   ""   ""   ""   ""
# 220   PPP (current international $)"  "NY.GDP.MKTP.PP.CD"   ""   ""   ""   ""
# 245   PPP (current international $)"  "NY.GDP.MKTP.PP.CD"   ""   ""   ""   ""
#
# 0   1965  ...                2015                2016                2017  \
# 88    ""  ...  "37816353965.5144"  "28095292742.1539"  "24861119032.1946"
# ...

# %%
#Filtered columns for desired years
years_columns = [str(year) for year in range(2000, 2023)]

# Select the desired columns
selected_columns = ['Country Name', 'Country Code'] + years_columns

# Create the new DataFrame
selected_columns = cleaned_gdp_df[selected_columns]

cleaned_gdp_df = selected_columns

cleaned_gdp_df.head(10)
# Out:
# 0                 Country Name Country Code                2000  \
# 0                        Aruba        "ABW"  "2489269108.56888"
# 1  Africa Eastern and Southern        "AFE"  "812829711711.237"
# 2                  Afghanistan        "AFG"                  ""
# 3   Africa Western and Central        "AFW"  "523136162568.061"
# 4                       Angola        "AGO"  "51115326928.9188"
# 5                      Albania        "ALB"  "10792578624.9517"
# 6                      Andorra        "AND"                  ""
# 7                   Arab World        "ARB"  "2603134800056.88"
# 8         United Arab Emirates        "ARE"  "271631571827.219"
# 9                    Argentina        "ARG"   "421755390917.54"
#
# 0                2001                2002                2003  \
# 0  "2739557506.26564"  "2918819032.73677"   "2935918444.3107"
# 1  "860197991571.217"  "911902650924.004"  "962534872974.799"
# 2                  ""                  ""  "19805683002.2132"
# ...

# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_gdp_df = cleaned_gdp_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_gdp_df.columns[2:25]:
    cleaned_gdp_df[column] = pd.to_numeric(cleaned_gdp_df[column], errors='coerce')

# %%
## Generate the list of columns from "2000" to "2022"
start_year = 2000
end_year = 2022
numerical_columns = [str(year) for year in range(start_year, end_year + 1)]

#Convert the columns to numeric values
cleaned_gdp_df[numerical_columns] = cleaned_gdp_df[numerical_columns].apply(pd.to_numeric)

# Divide the columns by 1 billion (1000000)
cleaned_gdp_df[numerical_columns] = cleaned_gdp_df[numerical_columns].div(1000000)    

# Display the updated DataFrame
cleaned_gdp_df.head()
# Out:
# 0                 Country Name Country Code           2000           2001  \
# 0                        Aruba          ABW    2489.269109    2739.557506
# 1  Africa Eastern and Southern          AFE  812829.711711  860197.991571
# 2                  Afghanistan          AFG            NaN            NaN
# 3   Africa Western and Central          AFW  523136.162568  554273.616200
# 4                       Angola          AGO   51115.326929   53870.124026
#
# 0           2002           2003          2004          2005          2006  \
# 0    2918.819033    2935.918444  3.027419e+03  3.335032e+03  3.426373e+03
# 1  911902.650924  962534.872975  1.013755e+06  1.099687e+06  1.204833e+06
# 2            NaN   19805.683002  2.198038e+04  2.288960e+04  2.625842e+04
# 3  596251.322889  662171.174205  7.124487e+05  7.892796e+05  8.613776e+05
# 4   57400.615763   66261.666029  6.958973e+04  7.928243e+04  9.405841e+04
#
# ...

# %%
#Perform data interpolation on the numeric columns
cleaned_gdp_df = cleaned_gdp_df.interpolate()
cleaned_gdp_df.head(5)
# Out:
# 0                 Country Name Country Code           2000           2001  \
# 0                        Aruba          ABW    2489.269109    2739.557506
# 1  Africa Eastern and Southern          AFE  812829.711711  860197.991571
# 2                  Afghanistan          AFG  667982.937140  707235.803886
# 3   Africa Western and Central          AFW  523136.162568  554273.616200
# 4                       Angola          AGO   51115.326929   53870.124026
#
# 0           2002           2003          2004          2005          2006  \
# 0    2918.819033    2935.918444  3.027419e+03  3.335032e+03  3.426373e+03
# 1  911902.650924  962534.872975  1.013755e+06  1.099687e+06  1.204833e+06
# 2  754076.986906   19805.683002  2.198038e+04  2.288960e+04  2.625842e+04
# 3  596251.322889  662171.174205  7.124487e+05  7.892796e+05  8.613776e+05
# 4   57400.615763   66261.666029  6.958973e+04  7.928243e+04  9.405841e+04
#
# ...

# %%
# Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_gdp_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="GDP")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year","Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year        GDP
# 0                  Afghanistan          AFG  2000  667982.94
# 1  Africa Eastern and Southern          AFE  2000  812829.71
# 2   Africa Western and Central          AFW  2000  523136.16
# 3                      Albania          ALB  2000   10792.58
# 4                      Algeria          DZA  2000  246725.43

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/GDP$.csv', index=False)
