# %%
#Import Dependancies
import pandas as pd
import os

# %%
#Import File
per_remitt = 'Personal_Remittance.csv'
per_remitt_df = pd.read_csv(per_remitt,  sep="\t")
per_remitt_df.head(10)
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2023-06-29",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Personal remittances, received (c...
# 3  Africa Eastern and Southern,"AFE","Personal re...
# 4  Afghanistan,"AFG","Personal remittances, recei...
# 5  Africa Western and Central,"AFW","Personal rem...
# 6  Angola,"AGO","Personal remittances, received (...
# 7  Albania,"ALB","Personal remittances, received ...
# 8  Andorra,"AND","Personal remittances, received ...
# 9  Arab World,"ARB","Personal remittances, receiv...

# %%
list(per_remitt_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = per_remitt_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
# Split columns
split_data = per_remitt_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
split_per_remitt_df = pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)


# Concatenate the remaining columns from original data
split_per_remitt_df = pd.concat([split_per_remitt_df, split_data.iloc[:, 4:]], axis=1)
split_per_remitt_df = split_per_remitt_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_per_remitt_df.head(10)
# Out:
#                   Country Name    Country Code         Indicator Name  \
# 0                 Country Name  "Country Code"       "Indicator Name"
# 1                        Aruba           "ABW"  "Personal remittances
# 2  Africa Eastern and Southern           "AFE"  "Personal remittances
# 3                  Afghanistan           "AFG"  "Personal remittances
# 4   Africa Western and Central           "AFW"  "Personal remittances
# 5                       Angola           "AGO"  "Personal remittances
# 6                      Albania           "ALB"  "Personal remittances
# 7                      Andorra           "AND"  "Personal remittances
# 8                   Arab World           "ARB"  "Personal remittances
# 9         United Arab Emirates           "ARE"  "Personal remittances
#
#              Indicator Code                    4       5       6       7  \
# 0          "Indicator Code"               "1960"  "1961"  "1962"  "1963"
# 1   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 2   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 3   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 4   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 5   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 6   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 7   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 8   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
# 9   received (current US$)"  "BX.TRF.PWKR.CD.DT"      ""      ""      ""
#
#         8       9  ...                  59                  60  \
# 0  "1964"  "1965"  ...              "2015"              "2016"
# 1      ""      ""  ...  "7465211.17318436"  "8083713.40782122"
# 2      ""      ""  ...  "10608587690.0081"  "10991481423.6928"
# 3      ""      ""  ...  "253367821.603343"  "348624717.302647"
# 4      ""      ""  ...  "29072581838.8663"  "31217369941.6298"
# 5      ""      ""  ...   "30971119.270778"        "11114711.6"
# 6      ""      ""  ...  "1421007454.36595"  "1290863508.09402"
# 7      ""      ""  ...                  ""                  ""
# 8      ""      ""  ...   "53122149553.083"  "49328023741.0255"
# 9      ""      ""  ...                  ""                  ""
#
#                    61                  62                  63  \
# 0              "2017"              "2018"              "2019"
# 1  "52682566.1467022"  "56140340.1581912"   "36920295.448098"
# 2  "10178689992.9643"  "10677675760.0106"  "14844760351.3452"
# 3  "627710802.377386"  "822731630.245558"  "803546453.786557"
# 4  "28385443647.8886"  "31597258310.6296"  "34559660467.4575"
# 5        "3988048.38"        "1418195.84"        "1579247.15"
# 6  "1306009166.92504"    "1311822432.138"  "1458210055.85311"
# 7                  ""                  ""                  ""
# 8  "48647574274.7084"  "51685563032.7971"  "54416712130.9952"
# 9                  ""                  ""                  ""
#
#                    64                  65                  66  \
# 0              "2020"              "2021"              "2022"
# 1   "34264018.270972"  "34984040.4172566"  "35845637.1605112"
# 2  "14398726897.8061"  "13764891638.0122"  "16275554661.6633"
# 3  "828571904.111179"   "788917115.24523"         "300000000"
# 4  "32586252955.0223"  "29206550132.4702"  "32148770623.1765"
# 5  "3445473.46759301"  "8053050.89441933"  "12631149.3197743"
# 6  "1472812241.61037"  "1465987212.49097"  "1718355918.32179"
# 7          "21100000"  "47416323.7388305"                  ""
# 8  "57002178442.6096"  "59467776316.4004"   "68619047376.259"
# 9                  ""                  ""                  ""
#
#                    67    68
# 0                      None
# 1  "38203853.3533978"
# 2  "18609324567.8369"
# 3         "350000000"
# 4  "33171084793.7117"
# 5  "14005491.4763133"
# 6  "1745245135.76651"
# 7                  ""
# 8  "68597506272.0447"
# 9                  ""
#
# [10 rows x 69 columns]

# %%
# Assign row 0 as column names
split_per_remitt_df.columns = split_per_remitt_df.iloc[0]

# Remove any quotation marks from column names
split_per_remitt_df.columns = split_per_remitt_df.columns.str.replace('"', '')

# Drop row 0 from the DataFrame
split_per_remitt_df = split_per_remitt_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_per_remitt_df.head(10)
# Out:
# 0                 Country Name Country Code         Indicator Name  \
# 0                        Aruba        "ABW"  "Personal remittances
# 1  Africa Eastern and Southern        "AFE"  "Personal remittances
# 2                  Afghanistan        "AFG"  "Personal remittances
# 3   Africa Western and Central        "AFW"  "Personal remittances
# 4                       Angola        "AGO"  "Personal remittances
# 5                      Albania        "ALB"  "Personal remittances
# 6                      Andorra        "AND"  "Personal remittances
# 7                   Arab World        "ARB"  "Personal remittances
# 8         United Arab Emirates        "ARE"  "Personal remittances
# 9                    Argentina        "ARG"  "Personal remittances
#
# 0            Indicator Code                 1960 1961 1962 1963 1964 1965  \
# 0   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 1   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 2   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 3   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 4   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 5   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 6   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 7   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 8   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
# 9   received (current US$)"  "BX.TRF.PWKR.CD.DT"   ""   ""   ""   ""   ""
#
# 0  ...                2015                2016                2017  \
# 0  ...  "7465211.17318436"  "8083713.40782122"  "52682566.1467022"
# 1  ...  "10608587690.0081"  "10991481423.6928"  "10178689992.9643"
# 2  ...  "253367821.603343"  "348624717.302647"  "627710802.377386"
# 3  ...  "29072581838.8663"  "31217369941.6298"  "28385443647.8886"
# 4  ...   "30971119.270778"        "11114711.6"        "3988048.38"
# 5  ...  "1421007454.36595"  "1290863508.09402"  "1306009166.92504"
# 6  ...                  ""                  ""                  ""
# 7  ...   "53122149553.083"  "49328023741.0255"  "48647574274.7084"
# 8  ...                  ""                  ""                  ""
# 9  ...  "505346891.730357"  "494433532.139966"  "391579047.663514"
#
# 0                2018                2019                2020  \
# 0  "56140340.1581912"   "36920295.448098"   "34264018.270972"
# 1  "10677675760.0106"  "14844760351.3452"  "14398726897.8061"
# 2  "822731630.245558"  "803546453.786557"  "828571904.111179"
# 3  "31597258310.6296"  "34559660467.4575"  "32586252955.0223"
# 4        "1418195.84"        "1579247.15"  "3445473.46759301"
# 5    "1311822432.138"  "1458210055.85311"  "1472812241.61037"
# 6                  ""                  ""          "21100000"
# 7  "51685563032.7971"  "54416712130.9952"  "57002178442.6096"
# 8                  ""                  ""                  ""
# 9  "479937459.808431"  "522441503.008565"  "561398444.719758"
#
# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_per_remitt_df = cleaned_per_remitt_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_per_remitt_df.columns[2:13]:
    cleaned_per_remitt_df[column] = pd.to_numeric(cleaned_per_remitt_df[column], errors='coerce')
    
# List of columns from "2010" to "2020"
numerical_columns = ["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]

# Divide the columns by 1 billion
cleaned_per_remitt_df[numerical_columns] = cleaned_per_remitt_df[numerical_columns].div(1000000)

# Display the updated DataFrame
cleaned_per_remitt_df.head()
# Out:
# 0                 Country Name Country Code          2010          2011  \
# 0                        Aruba          ABW      9.050279      4.972067
# 1  Africa Eastern and Southern          AFE   6529.047868   7855.156172
# 2                  Afghanistan          AFG    140.695166    378.206657
# 3   Africa Western and Central          AFW  21884.173259  23801.903317
# 4                       Angola          AGO      0.162358     17.972037
#
# 0          2012          2013          2014          2015          2016  \
# 0      5.307263      4.860335      6.337951      7.465211      8.083713
# 1   9436.898842   9539.966327   9473.592326  10608.587690  10991.481424
# 2    179.116561    219.416087    347.165292    253.367822    348.624717
# 3  27623.774682  27691.377000  28076.823908  29072.581839  31217.369942
# 4      0.204751     40.348854     36.637411     30.971119     11.114712
#
# 0          2017          2018          2019          2020
# 0     52.682566     56.140340     36.920295     34.264018
# 1  10178.689993  10677.675760  14844.760351  14398.726898
# 2    627.710802    822.731630    803.546454    828.571904
# 3  28385.443648  31597.258311  34559.660467  32586.252955
# 4      3.988048      1.418196      1.579247      3.445473

# %%
# Replace the NaN values with 0
cleaned_per_remitt_df.fillna(0, inplace=True)

cleaned_per_remitt_df.head(10)
# Out:
# 0                 Country Name Country Code          2010          2011  \
# 0                        Aruba          ABW      9.050279      4.972067
# 1  Africa Eastern and Southern          AFE   6529.047868   7855.156172
# 2                  Afghanistan          AFG    140.695166    378.206657
# 3   Africa Western and Central          AFW  21884.173259  23801.903317
# 4                       Angola          AGO      0.162358     17.972037
# 5                      Albania          ALB   1717.698012   1586.574271
# 6                      Andorra          AND      0.000000      0.000000
# 7                   Arab World          ARB  31754.690365  37780.646735
# 8         United Arab Emirates          ARE      0.000000      0.000000
# 9                    Argentina          ARG    628.542376    644.300740
#
# 0          2012          2013          2014          2015          2016  \
# 0      5.307263      4.860335      6.337951      7.465211      8.083713
# 1   9436.898842   9539.966327   9473.592326  10608.587690  10991.481424
# 2    179.116561    219.416087    347.165292    253.367822    348.624717
# 3  27623.774682  27691.377000  28076.823908  29072.581839  31217.369942
# 4      0.204751     40.348854     36.637411     30.971119     11.114712
# 5   1552.078514   1419.772515   1281.848114   1421.007454   1290.863508
# 6      0.000000      0.000000      0.000000      0.000000      0.000000
# 7  38944.864662  45933.616317  47228.856825  53122.149553  49328.023741
# 8      0.000000      0.000000      0.000000      0.000000      0.000000
# 9    697.379575    577.532962    535.004409    505.346892    494.433532
#
# 0          2017          2018          2019          2020
# 0     52.682566     56.140340     36.920295     34.264018
# 1  10178.689993  10677.675760  14844.760351  14398.726898
# 2    627.710802    822.731630    803.546454    828.571904
# 3  28385.443648  31597.258311  34559.660467  32586.252955
# 4      3.988048      1.418196      1.579247      3.445473
# 5   1306.009167   1311.822432   1458.210056   1472.812242
# 6      0.000000      0.000000      0.000000     21.100000
# 7  48647.574275  51685.563033  54416.712131  57002.178443
# 8      0.000000      0.000000      0.000000      0.000000
# 9    391.579048    479.937460    522.441503    561.398445

# %%
# Calculate the average for each country
average_by_country = cleaned_per_remitt_df.groupby('Country Code').apply(lambda group: group.drop(columns=['Country Name', 'Country Code']).mean(skipna=True, axis=1))

# Replace all 0.0 values with the corresponding country average
for col in cleaned_per_remitt_df.columns[2:]:
    cleaned_per_remitt_df[col] = cleaned_per_remitt_df.apply(lambda row: average_by_country[row['Country Code']][row.name] if row[col] == 0.0 else row[col], axis=1)

cleaned_per_remitt_df.head(10)
# Out:
# 0                 Country Name Country Code          2010          2011  \
# 0                        Aruba          ABW      9.050279      4.972067
# 1  Africa Eastern and Southern          AFE   6529.047868   7855.156172
# 2                  Afghanistan          AFG    140.695166    378.206657
# 3   Africa Western and Central          AFW  21884.173259  23801.903317
# 4                       Angola          AGO      0.162358     17.972037
# 5                      Albania          ALB   1717.698012   1586.574271
# 6                      Andorra          AND      1.918182      1.918182
# 7                   Arab World          ARB  31754.690365  37780.646735
# 8         United Arab Emirates          ARE      0.000000      0.000000
# 9                    Argentina          ARG    628.542376    644.300740
#
# 0          2012          2013          2014          2015          2016  \
# 0      5.307263      4.860335      6.337951      7.465211      8.083713
# 1   9436.898842   9539.966327   9473.592326  10608.587690  10991.481424
# 2    179.116561    219.416087    347.165292    253.367822    348.624717
# 3  27623.774682  27691.377000  28076.823908  29072.581839  31217.369942
# 4      0.204751     40.348854     36.637411     30.971119     11.114712
# 5   1552.078514   1419.772515   1281.848114   1421.007454   1290.863508
# 6      1.918182      1.918182      1.918182      1.918182      1.918182
# 7  38944.864662  45933.616317  47228.856825  53122.149553  49328.023741
# 8      0.000000      0.000000      0.000000      0.000000      0.000000
# 9    697.379575    577.532962    535.004409    505.346892    494.433532
#
# 0          2017          2018          2019          2020
# 0     52.682566     56.140340     36.920295     34.264018
# 1  10178.689993  10677.675760  14844.760351  14398.726898
# 2    627.710802    822.731630    803.546454    828.571904
# 3  28385.443648  31597.258311  34559.660467  32586.252955
# 4      3.988048      1.418196      1.579247      3.445473
# 5   1306.009167   1311.822432   1458.210056   1472.812242
# 6      1.918182      1.918182      1.918182     21.100000
# 7  48647.574275  51685.563033  54416.712131  57002.178443
# 8      0.000000      0.000000      0.000000      0.000000
# 9    391.579048    479.937460    522.441503    561.398445

# %%
# Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_per_remitt_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Personal Remittance ($M)")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year", "Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year  Personal Remittance ($M)
# 0                  Afghanistan          AFG  2010                    140.70
# 1  Africa Eastern and Southern          AFE  2010                   6529.05
# 2   Africa Western and Central          AFW  2010                  21884.17
# 3                      Albania          ALB  2010                   1717.70
# 4                      Algeria          DZA  2010                    150.34

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/Personal_Remittance.csv', index=False)
