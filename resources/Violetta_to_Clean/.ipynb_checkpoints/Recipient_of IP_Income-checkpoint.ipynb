# %%
#Import Dependancies
import pandas as pd
import os

# %%
#Import File
ip_income = 'Recipient_of IP_Income.csv'
ip_income_df = pd.read_csv(ip_income,  sep="\t")
ip_income_df.head(10)
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2023-06-29",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Charges for the use of intellectu...
# 3  Africa Eastern and Southern,"AFE","Charges for...
# 4  Afghanistan,"AFG","Charges for the use of inte...
# 5  Africa Western and Central,"AFW","Charges for ...
# 6  Angola,"AGO","Charges for the use of intellect...
# 7  Albania,"ALB","Charges for the use of intellec...
# 8  Andorra,"AND","Charges for the use of intellec...
# 9  Arab World,"ARB","Charges for the use of intel...

# %%
list(ip_income_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = ip_income_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
# Split columns
split_data = ip_income_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
split_ip_income_df = pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)


# Concatenate the remaining columns from original data
split_ip_income_df = pd.concat([split_ip_income_df, split_data.iloc[:, 4:]], axis=1)
split_ip_income_df = split_ip_income_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_ip_income_df.head(10)
# Out:
#                   Country Name    Country Code  \
# 0                 Country Name  "Country Code"
# 1                        Aruba           "ABW"
# 2  Africa Eastern and Southern           "AFE"
# 3                  Afghanistan           "AFG"
# 4   Africa Western and Central           "AFW"
# 5                       Angola           "AGO"
# 6                      Albania           "ALB"
# 7                      Andorra           "AND"
# 8                   Arab World           "ARB"
# 9         United Arab Emirates           "ARE"
#
#                                   Indicator Name    Indicator Code  \
# 0                               "Indicator Name"  "Indicator Code"
# 1  "Charges for the use of intellectual property     payments (BoP
# 2  "Charges for the use of intellectual property     payments (BoP
# 3  "Charges for the use of intellectual property     payments (BoP
# 4  "Charges for the use of intellectual property     payments (BoP
# ...

# %%
# Assign row 0 as column names
split_ip_income_df.columns = split_ip_income_df.iloc[0]

# Remove any quotation marks from column names
split_ip_income_df.columns = split_ip_income_df.columns.str.replace('"', '')

# Drop row 0 from the DataFrame
split_ip_income_df = split_ip_income_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
split_ip_income_df.head(10)
# Out:
# 0                 Country Name Country Code  \
# 0                        Aruba        "ABW"
# 1  Africa Eastern and Southern        "AFE"
# 2                  Afghanistan        "AFG"
# 3   Africa Western and Central        "AFW"
# 4                       Angola        "AGO"
# 5                      Albania        "ALB"
# 6                      Andorra        "AND"
# 7                   Arab World        "ARB"
# 8         United Arab Emirates        "ARE"
# 9                    Argentina        "ARG"
#
# 0                                 Indicator Name  Indicator Code  \
# 0  "Charges for the use of intellectual property   payments (BoP
# 1  "Charges for the use of intellectual property   payments (BoP
# 2  "Charges for the use of intellectual property   payments (BoP
# 3  "Charges for the use of intellectual property   payments (BoP
# 4  "Charges for the use of intellectual property   payments (BoP
# 5  "Charges for the use of intellectual property   payments (BoP
# ...

# %%
#Filtered columns for desired years
years_columns = [str(year) for year in range(2000, 2023)]

# Select the desired columns
selected_columns = ['Country Name', 'Country Code'] + years_columns

# Create the new DataFrame
selected_columns = split_ip_income_df[selected_columns]

cleaned_ip_income_df = selected_columns

cleaned_ip_income_df.head(10)
# Out:
# 0                 Country Name Country Code                2000  \
# 0                        Aruba        "ABW"                  ""
# 1  Africa Eastern and Southern        "AFE"   "343401984.91352"
# 2                  Afghanistan        "AFG"                  ""
# 3   Africa Western and Central        "AFW"    "7558945.356209"
# 4                       Angola        "AGO"           "1170000"
# 5                      Albania        "ALB"                  ""
# 6                      Andorra        "AND"                  ""
# 7                   Arab World        "ARB"  "566753377.636297"
# 8         United Arab Emirates        "ARE"                  ""
# 9                    Argentina        "ARG"  "590352559.088508"
#
# 0                2001                2002                2003  \
# 0  "480446.927374302"  "458100.558659218"  "1564245.81005587"
# 1  "329550880.441077"  "396369882.141538"  "458714373.790437"
# 2                  ""                  ""                  ""
# ...

# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_ip_income_df = cleaned_ip_income_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_ip_income_df.columns[2:25]:
    cleaned_ip_income_df[column] = pd.to_numeric(cleaned_ip_income_df[column], errors='coerce')
    
# Generate the list of columns from "2000" to "2022"
start_year = 2000
end_year = 2022
numerical_columns = [str(year) for year in range(start_year, end_year + 1)]
    
# Divide the columns by 1 billion
cleaned_ip_income_df[numerical_columns] = cleaned_ip_income_df[numerical_columns].div(1000000)    

# Display the updated DataFrame
cleaned_ip_income_df.head()
# Out:
# 0                 Country Name Country Code        2000        2001  \
# 0                        Aruba          ABW         NaN    0.480447
# 1  Africa Eastern and Southern          AFE  343.401985  329.550880
# 2                  Afghanistan          AFG         NaN         NaN
# 3   Africa Western and Central          AFW    7.558945   11.836951
# 4                       Angola          AGO    1.170000    1.660000
#
# 0        2002        2003        2004        2005         2006         2007  \
# 0    0.458101    1.564246    3.391061    4.217877     4.547486     6.771959
# 1  396.369882  458.714374  587.668404  762.155199  1066.498400  1260.750200
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3   12.565897    8.571819    7.642541   56.895380    15.260468   105.306761
# 4    5.630000    0.430000         NaN         NaN     2.495000     3.378446
#
# 0  ...         2013         2014         2015         2016         2017  \
# ...

# %%
# Perform data interpolation on the numeric columns
cleaned_ip_income_df = cleaned_ip_income_df.interpolate()
cleaned_ip_income_df.head(5)
# Out:
# 0                 Country Name Country Code        2000        2001  \
# 0                        Aruba          ABW         NaN    0.480447
# 1  Africa Eastern and Southern          AFE  343.401985  329.550880
# 2                  Afghanistan          AFG  175.480465  170.693916
# 3   Africa Western and Central          AFW    7.558945   11.836951
# 4                       Angola          AGO    1.170000    1.660000
#
# 0        2002        2003        2004        2005         2006         2007  \
# 0    0.458101    1.564246    3.391061    4.217877     4.547486     6.771959
# 1  396.369882  458.714374  587.668404  762.155199  1066.498400  1260.750200
# 2  204.467889  233.643096  297.655472  409.525290   540.879434   683.028480
# 3   12.565897    8.571819    7.642541   56.895380    15.260468   105.306761
# 4    5.630000    0.430000   60.747916   32.627119     2.495000     3.378446
#
# 0  ...         2013         2014         2015         2016         2017  \
# ...

# %%
# Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_ip_income_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="IP Income($M)")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year", "Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year  IP Income($M)
# 0                  Afghanistan          AFG  2000         175.48
# 1  Africa Eastern and Southern          AFE  2000         343.40
# 2   Africa Western and Central          AFW  2000           7.56
# 3                      Albania          ALB  2000         189.70
# 4                      Algeria          DZA  2000         516.94

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/IP_Income.csv', index=False)
