# %%
import pandas as pd
import os

# %%
#Import File
atm = "ATM.csv"
atm_df = pd.read_csv(atm, sep="\t")
atm_df.head(10)
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2023-06-29",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Automated teller machines (ATMs) ...
# 3  Africa Eastern and Southern,"AFE","Automated t...
# 4  Afghanistan,"AFG","Automated teller machines (...
# 5  Africa Western and Central,"AFW","Automated te...
# 6  Angola,"AGO","Automated teller machines (ATMs)...
# 7  Albania,"ALB","Automated teller machines (ATMs...
# 8  Andorra,"AND","Automated teller machines (ATMs...
# 9  Arab World,"ARB","Automated teller machines (A...

# %%
list(atm_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = atm_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
split_data = atm_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
cleaned_atm_df = pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)

# Concatenate the remaining columns from split_data to cleaned_atm_df
cleaned_atm_df = pd.concat([cleaned_atm_df, split_data.iloc[:, 4:]], axis=1)
cleaned_atm_df = cleaned_atm_df.drop(index=0).reset_index(drop=True)
# Display the cleaned DataFrame
cleaned_atm_df.head(5)
# Out:
#                   Country Name    Country Code  \
# 0                 Country Name  "Country Code"
# 1                        Aruba           "ABW"
# 2  Africa Eastern and Southern           "AFE"
# 3                  Afghanistan           "AFG"
# 4   Africa Western and Central           "AFW"
#
#                                Indicator Name    Indicator Code  \
# 0                            "Indicator Name"  "Indicator Code"
# 1  "Automated teller machines (ATMs) (per 100      000 adults)"
# 2  "Automated teller machines (ATMs) (per 100      000 adults)"
# 3  "Automated teller machines (ATMs) (per 100      000 adults)"
# 4  "Automated teller machines (ATMs) (per 100      000 adults)"
#
#                   4       5       6       7       8       9  ...        59  \
# 0            "1960"  "1961"  "1962"  "1963"  "1964"  "1965"  ...    "2015"
# 1  "FB.ATM.TOTL.P5"      ""      ""      ""      ""      ""  ...  "117.94"
# 2  "FB.ATM.TOTL.P5"      ""      ""      ""      ""      ""  ...   "7.625"
# 3  "FB.ATM.TOTL.P5"      ""      ""      ""      ""      ""  ...    "0.75"
# 4  "FB.ATM.TOTL.P5"      ""      ""      ""      ""      ""  ...    "4.55"
#
#          60        61        62        63        64       65        66  67  \
# 0    "2016"    "2017"    "2018"    "2019"    "2020"   "2021"    "2022"
# 1  "119.07"  "125.99"  "124.98"  "126.43"  "126.74"  "121.3"  "117.34"  ""
# 2    "9.69"    "9.16"   "10.25"   "9.985"  "10.265"  "9.905"   "8.935"  ""
# 3    "0.92"    "1.06"    "1.21"    "1.61"    "1.64"       ""        ""  ""
# 4    "4.46"    "4.98"     "5.3"    "5.37"       "6"   "6.39"    "6.82"  ""
#
#      68
# 0  None
# 1
# 2
# 3
# 4
#
# [5 rows x 69 columns]

# %%
# Assign row 0 as column names
cleaned_atm_df.columns = cleaned_atm_df.iloc[0]
cleaned_atm_df.columns = cleaned_atm_df.columns.str.replace('"', '')  # Remove any quotation marks from column names

# Drop row 0 from the DataFrame
cleaned_atm_df = cleaned_atm_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
cleaned_atm_df.head(5)
# Out:
# 0                 Country Name Country Code  NaN  NaN  NaN  NaN  NaN  NaN  \
# 0                        Aruba          ABW  NaN  NaN  NaN  NaN  NaN  NaN
# 1  Africa Eastern and Southern          AFE  NaN  NaN  NaN  NaN  NaN  NaN
# 2                  Afghanistan          AFG  NaN  NaN  NaN  NaN  NaN  NaN
# 3   Africa Western and Central          AFW  NaN  NaN  NaN  NaN  NaN  NaN
# 4                       Angola          AGO  NaN  NaN  NaN  NaN  NaN  NaN
#
# 0  NaN  NaN  ...    2015    2016    2017    2018    2019    2020   2021  \
# 0  NaN  NaN  ...  117.94  119.07  125.99  124.98  126.43  126.74  121.3
# 1  NaN  NaN  ...   7.625    9.69    9.16   10.25   9.985  10.265  9.905
# 2  NaN  NaN  ...    0.75    0.92    1.06    1.21    1.61    1.64
# 3  NaN  NaN  ...    4.55    4.46    4.98     5.3    5.37       6   6.39
# 4  NaN  NaN  ...   18.19   18.82   19.06   19.13   18.92    18.4  17.87
#
# 0    2022   None
# 0  117.34
# 1   8.935
# 2
# 3    6.82
# 4   17.77
#
# [5 rows x 69 columns]

# %%
#Filtered columns for desired years
years_columns = [str(year) for year in range(2010, 2021)]

# Select the desired columns
selected_columns = ['Country Name', 'Country Code'] + years_columns

# Create the new DataFrame
selected_columns = cleaned_atm_df[selected_columns]

cleaned_atm_df = selected_columns

cleaned_atm_df.head(10)
# Out:
# 0                 Country Name Country Code    2010   2011    2012    2013  \
# 0                        Aruba          ABW                 110.98  119.57
# 1  Africa Eastern and Southern          AFE   5.455   5.57    4.76    5.25
# 2                  Afghanistan          AFG    0.45   0.53    0.62    0.64
# 3   Africa Western and Central          AFW   1.545   1.65    2.34    2.58
# 4                       Angola          AGO    8.34  10.42   12.72   15.19
# 5                      Albania          ALB   32.94  34.13   35.29   35.74
# 6                      Andorra          AND
# 7                   Arab World          ARB  15.995  19.66   18.92  20.435
# 8         United Arab Emirates          ARE   52.65  50.61   53.86   56.86
# 9                    Argentina          ARG   13.86  19.29   27.05   34.53
#
# 0    2014    2015    2016    2017    2018    2019    2020
# 0  124.17  117.94  119.07  125.99  124.98  126.43  126.74
# 1   6.735   7.625    9.69    9.16   10.25   9.985  10.265
# 2    0.71    0.75    0.92    1.06    1.21    1.61    1.64
# 3   4.025    4.55    4.46    4.98     5.3    5.37       6
# 4   16.99   18.19   18.82   19.06   19.13   18.92    18.4
# 5   35.43   34.75   35.26   34.08   31.71   30.64   29.99
# 6
# 7   23.14    24.5  23.595   26.71   27.21   27.79   28.58
# 8   58.78   61.12   64.38   65.42   65.37   64.48   60.91
# 9   43.34   45.67   47.51   50.35   53.12   58.98   60.75

# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_atm_df = cleaned_atm_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_atm_df.columns[2:13]:
    cleaned_atm_df[column] = pd.to_numeric(cleaned_atm_df[column], errors='coerce')

# Display the updated DataFrame
cleaned_atm_df.head(25)
# Out:
# 0                  Country Name Country Code     2010    2011    2012  \
# 0                         Aruba          ABW      NaN     NaN  110.98
# 1   Africa Eastern and Southern          AFE    5.455    5.57    4.76
# 2                   Afghanistan          AFG    0.450    0.53    0.62
# 3    Africa Western and Central          AFW    1.545    1.65    2.34
# 4                        Angola          AGO    8.340   10.42   12.72
# 5                       Albania          ALB   32.940   34.13   35.29
# 6                       Andorra          AND      NaN     NaN     NaN
# 7                    Arab World          ARB   15.995   19.66   18.92
# 8          United Arab Emirates          ARE   52.650   50.61   53.86
# 9                     Argentina          ARG   13.860   19.29   27.05
# 10                      Armenia          ARM   30.240   34.05   43.54
# 11               American Samoa          ASM      NaN     NaN     NaN
# 12          Antigua and Barbuda          ATG   69.030   72.07   73.75
# 13                    Australia          AUS  154.320  168.69  170.51
# 14                      Austria          AUT  112.340  112.92  113.80
# 15                   Azerbaijan          AZE   24.670   27.08   30.03
# 16                      Burundi          BDI    0.280    0.53    0.71
# 17                      Belgium          BEL   87.370   91.76   93.32
# 18                        Benin          BEN      NaN     NaN     NaN
# 19                 Burkina Faso          BFA      NaN     NaN     NaN
# 20                   Bangladesh          BGD    1.290    2.11    3.71
# 21                     Bulgaria          BGR   87.820   90.55   93.86
# 22                      Bahrain          BHR      NaN     NaN     NaN
# 23                      Bahamas          The   70.220   71.54   70.90
# 24       Bosnia and Herzegovina          BIH   43.240   35.17   38.96
#
# 0      2013     2014     2015     2016    2017    2018     2019     2020
# 0   119.570  124.170  117.940  119.070  125.99  124.98  126.430  126.740
# 1     5.250    6.735    7.625    9.690    9.16   10.25    9.985   10.265
# 2     0.640    0.710    0.750    0.920    1.06    1.21    1.610    1.640
# 3     2.580    4.025    4.550    4.460    4.98    5.30    5.370    6.000
# 4    15.190   16.990   18.190   18.820   19.06   19.13   18.920   18.400
# 5    35.740   35.430   34.750   35.260   34.08   31.71   30.640   29.990
# 6       NaN      NaN      NaN      NaN     NaN     NaN      NaN      NaN
# 7    20.435   23.140   24.500   23.595   26.71   27.21   27.790   28.580
# 8    56.860   58.780   61.120   64.380   65.42   65.37   64.480   60.910
# 9    34.530   43.340   45.670   47.510   50.35   53.12   58.980   60.750
# 10   50.400   53.910   59.430   60.560   61.16   63.74   64.110   65.540
# 11      NaN      NaN      NaN      NaN     NaN     NaN      NaN      NaN
# 12   75.340   79.740   77.060   74.540   68.17   66.03   66.650   65.970
# 13  164.700  161.170  165.230  163.900  167.70  160.32  146.170  136.540
# 14  115.630  117.270  186.370  183.270  162.92  165.04  169.410  171.910
# 15   31.390   33.240   35.410   36.200   32.72   32.16   32.850   34.490
# 16    0.990    1.550    1.510    1.430    1.42     NaN      NaN      NaN
# 17   94.230   93.950   90.930   90.020   88.34   87.45   80.970   75.190
# 18      NaN      NaN    3.510    3.690    3.88    3.84    4.870    4.780
# 19      NaN      NaN      NaN    4.460    4.81    5.37    4.180    5.150
# 20    4.040    4.960    5.770    7.090    8.03    8.36    8.920    9.420
# 21   93.120   93.740   90.480   91.270   94.16   94.77   93.400   94.330
# 22      NaN      NaN      NaN      NaN     NaN     NaN      NaN      NaN
# 23   82.010   80.480  112.870  119.460  121.30  138.78  122.950  127.790
# 24   42.190   45.630   48.310   51.920   52.48   53.89   55.840   58.240

# %%
#Perform data interpolation on the numeric columns
cleaned_atm_df = cleaned_atm_df.interpolate(method='linear')
cleaned_atm_df.head(25)
# Out:
# 0                  Country Name Country Code        2010        2011     2012  \
# 0                         Aruba          ABW         NaN         NaN  110.980
# 1   Africa Eastern and Southern          AFE    5.455000    5.570000    4.760
# 2                   Afghanistan          AFG    0.450000    0.530000    0.620
# 3    Africa Western and Central          AFW    1.545000    1.650000    2.340
# 4                        Angola          AGO    8.340000   10.420000   12.720
# 5                       Albania          ALB   32.940000   34.130000   35.290
# 6                       Andorra          AND   24.467500   26.895000   27.105
# 7                    Arab World          ARB   15.995000   19.660000   18.920
# 8          United Arab Emirates          ARE   52.650000   50.610000   53.860
# 9                     Argentina          ARG   13.860000   19.290000   27.050
# 10                      Armenia          ARM   30.240000   34.050000   43.540
# 11               American Samoa          ASM   49.635000   53.060000   58.645
# 12          Antigua and Barbuda          ATG   69.030000   72.070000   73.750
# 13                    Australia          AUS  154.320000  168.690000  170.510
# 14                      Austria          AUT  112.340000  112.920000  113.800
# 15                   Azerbaijan          AZE   24.670000   27.080000   30.030
# 16                      Burundi          BDI    0.280000    0.530000    0.710
# 17                      Belgium          BEL   87.370000   91.760000   93.320
# 18                        Benin          BEN   58.676667   61.876667   63.450
# 19                 Burkina Faso          BFA   29.983333   31.993333   33.580
# 20                   Bangladesh          BGD    1.290000    2.110000    3.710
# 21                     Bulgaria          BGR   87.820000   90.550000   93.860
# 22                      Bahrain          BHR   79.020000   81.045000   82.380
# 23                      Bahamas          The   70.220000   71.540000   70.900
# 24       Bosnia and Herzegovina          BIH   43.240000   35.170000   38.960
#
# 0         2013        2014     2015      2016     2017     2018     2019  \
# 0   119.570000  124.170000  117.940  119.0700  125.990  124.980  126.430
# 1     5.250000    6.735000    7.625    9.6900    9.160   10.250    9.985
# 2     0.640000    0.710000    0.750    0.9200    1.060    1.210    1.610
# 3     2.580000    4.025000    4.550    4.4600    4.980    5.300    5.370
# 4    15.190000   16.990000   18.190   18.8200   19.060   19.130   18.920
# 5    35.740000   35.430000   34.750   35.2600   34.080   31.710   30.640
# 6    28.087500   29.285000   29.625   29.4275   30.395   29.460   29.215
# 7    20.435000   23.140000   24.500   23.5950   26.710   27.210   27.790
# 8    56.860000   58.780000   61.120   64.3800   65.420   65.370   64.480
# 9    34.530000   43.340000   45.670   47.5100   50.350   53.120   58.980
# 10   50.400000   53.910000   59.430   60.5600   61.160   63.740   64.110
# 11   62.870000   66.825000   68.245   67.5500   64.665   64.885   65.380
# 12   75.340000   79.740000   77.060   74.5400   68.170   66.030   66.650
# 13  164.700000  161.170000  165.230  163.9000  167.700  160.320  146.170
# 14  115.630000  117.270000  186.370  183.2700  162.920  165.040  169.410
# 15   31.390000   33.240000   35.410   36.2000   32.720   32.160   32.850
# 16    0.990000    1.550000    1.510    1.4300    1.420   59.805   56.910
# 17   94.230000   93.950000   90.930   90.0200   88.340   87.450   80.970
# 18   64.166667   64.286667    3.510    3.6900    3.880    3.840    4.870
# 19   34.103333   34.623333    4.640    4.4600    4.810    5.370    4.180
# 20    4.040000    4.960000    5.770    7.0900    8.030    8.360    8.920
# 21   93.120000   93.740000   90.480   91.2700   94.160   94.770   93.400
# 22   87.565000   87.110000  101.675  105.3650  107.730  116.775  108.175
# 23   82.010000   80.480000  112.870  119.4600  121.300  138.780  122.950
# 24   42.190000   45.630000   48.310   51.9200   52.480   53.890   55.840
#
# 0      2020
# 0   126.740
# 1    10.265
# 2     1.640
# 3     6.000
# 4    18.400
# 5    29.990
# 6    29.285
# 7    28.580
# 8    60.910
# 9    60.750
# 10   65.540
# 11   65.755
# 12   65.970
# 13  136.540
# 14  171.910
# 15   34.490
# 16   54.840
# 17   75.190
# 18    4.780
# 19    5.150
# 20    9.420
# 21   94.330
# 22  111.060
# 23  127.790
# 24   58.240

# %%
# Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_atm_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="ATM Usage")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year","Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage
# 0                  Afghanistan          AFG  2010       0.45
# 1  Africa Eastern and Southern          AFE  2010       5.46
# 2   Africa Western and Central          AFW  2010       1.54
# 3                      Albania          ALB  2010      32.94
# 4                      Algeria          DZA  2010       5.33

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/ATM_Usage.csv', index=False)
