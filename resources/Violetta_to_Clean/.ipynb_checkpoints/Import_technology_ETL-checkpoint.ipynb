# %%
import pandas as pd
import os

# %%
import_tech = "Import_technology.csv"
import_tech_df = pd.read_csv(import_tech, sep="\t")
import_tech_df
# Out:
#            Data Source,"World Development Indicators",
# 0                      Last Updated Date,"2023-06-29",
# 1    Country Name,"Country Code","Indicator Name","...
# 2    Aruba,"ABW","Communications, computer, etc. (%...
# 3    Africa Eastern and Southern,"AFE","Communicati...
# 4    Afghanistan,"AFG","Communications, computer, e...
# ..                                                 ...
# 263  Kosovo,"XKX","Communications, computer, etc. (...
# 264  Yemen, Rep.,"YEM","Communications, computer, e...
# 265  South Africa,"ZAF","Communications, computer, ...
# 266  Zambia,"ZMB","Communications, computer, etc. (...
# 267  Zimbabwe,"ZWE","Communications, computer, etc....
#
# [268 rows x 1 columns]

# %%
list(import_tech_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = import_tech_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
split_data = import_tech_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
cleaned_import_tech_df = pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)

# Concatenate the remaining columns from split_data to cleaned_atm_df
cleaned_import_tech_df = pd.concat([cleaned_import_tech_df, split_data.iloc[:, 4:]], axis=1)
cleaned_import_tech_df = cleaned_import_tech_df.drop(index=0).reset_index(drop=True)
# Display the cleaned DataFrame
cleaned_import_tech_df.head(5)
# Out:
#                   Country Name    Country Code    Indicator Name  \
# 0                 Country Name  "Country Code"  "Indicator Name"
# 1                        Aruba           "ABW"   "Communications
# 2  Africa Eastern and Southern           "AFE"   "Communications
# 3                  Afghanistan           "AFG"   "Communications
# 4   Africa Western and Central           "AFW"   "Communications
#
#      Indicator Code                            4       5                 6  \
# 0  "Indicator Code"                       "1960"  "1961"            "1962"
# 1          computer   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"
# 2          computer   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"
# 3          computer   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"
# 4          computer   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"
#
#         7       8       9  ...                  59                  60  \
# ...

# %%
# Assign row 0 as column names
cleaned_import_tech_df.columns = cleaned_import_tech_df.iloc[0]

# Remove any quotation marks from column names
cleaned_import_tech_df.columns = cleaned_import_tech_df.columns.str.replace('"', '')  

# Drop row 0 from the DataFrame
cleaned_import_tech_df = cleaned_import_tech_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
cleaned_import_tech_df.head(5)
# Out:
# 0                 Country Name Country Code   Indicator Name Indicator Code  \
# 0                        Aruba        "ABW"  "Communications       computer
# 1  Africa Eastern and Southern        "AFE"  "Communications       computer
# 2                  Afghanistan        "AFG"  "Communications       computer
# 3   Africa Western and Central        "AFW"  "Communications       computer
# 4                       Angola        "AGO"  "Communications       computer
#
# 0                         1960    1961              1962 1963 1964 1965  ...  \
# 0   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"   ""   ""   ""  ...
# 1   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"   ""   ""   ""  ...
# 2   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"   ""   ""   ""  ...
# 3   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"   ""   ""   ""  ...
# 4   etc. (% of service imports   BoP)"  "BM.GSR.CMCP.ZS"   ""   ""   ""  ...
#
# ...

# %%
# Define a function to remove double quotes from each cell
def remove_quotes(cell_value):
    if cell_value is not None:
        return cell_value.replace('"', '')
    else:
        return cell_value

# Use applymap() to remove double quotes from the entire DataFrame
cleaned_import_tech_df = cleaned_import_tech_df.applymap(remove_quotes)

# Display the first five rows of the cleaned DataFrame
cleaned_import_tech_df.head(5)
# Out:
# 0                 Country Name Country Code  Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Communications       computer
# 1  Africa Eastern and Southern          AFE  Communications       computer
# 2                  Afghanistan          AFG  Communications       computer
# 3   Africa Western and Central          AFW  Communications       computer
# 4                       Angola          AGO  Communications       computer
#
# 0                         1960   1961            1962 1963 1964 1965  ...  \
# 0   etc. (% of service imports   BoP)  BM.GSR.CMCP.ZS                 ...
# 1   etc. (% of service imports   BoP)  BM.GSR.CMCP.ZS                 ...
# 2   etc. (% of service imports   BoP)  BM.GSR.CMCP.ZS                 ...
# 3   etc. (% of service imports   BoP)  BM.GSR.CMCP.ZS                 ...
# 4   etc. (% of service imports   BoP)  BM.GSR.CMCP.ZS                 ...
#
# ...

# %%
#Filtered columns for desired years
years_columns = [str(year) for year in range(2000, 2023)]

# Select the desired columns
selected_columns = ['Country Name', 'Country Code'] + years_columns

# Create the new DataFrame
selected_columns = cleaned_import_tech_df[selected_columns]

cleaned_import_tech_df = selected_columns

cleaned_import_tech_df.head(10)
# Out:
# 0                 Country Name Country Code              2000  \
# 0                        Aruba          ABW   77.297780426039
# 1  Africa Eastern and Southern          AFE  34.5720573027855
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW  45.2728591368966
# 4                       Angola          AGO  79.3987149864513
# 5                      Albania          ALB  29.3479440164913
# 6                      Andorra          AND
# 7                   Arab World          ARB
# 8         United Arab Emirates          ARE
# 9                    Argentina          ARG  18.5986892396551
#
# 0              2001              2002              2003              2004  \
# 0  69.9155328511459  45.7388552098335  32.3240511568943  33.0457125675392
# 1  37.1724815516875  34.5182338758995  34.0759875018078  38.6467810374381
# 2
# 3  43.9611961372953  49.5663182679511  50.9260776554019  50.9767580969221
# ...

# %%
# Clean DF and Convert Columns

# Remove the quotation marks from all columns
cleaned_import_tech_df = cleaned_import_tech_df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)

# Convert columns the Years to float data type
for column in cleaned_import_tech_df.columns[2:25]:
    cleaned_import_tech_df[column] = pd.to_numeric(cleaned_import_tech_df[column], errors='coerce')
    
# Display the updated DataFrame
cleaned_import_tech_df.head()
# Out:
# 0                 Country Name Country Code       2000       2001       2002  \
# 0                        Aruba          ABW  77.297780  69.915533  45.738855
# 1  Africa Eastern and Southern          AFE  34.572057  37.172482  34.518234
# 2                  Afghanistan          AFG        NaN        NaN        NaN
# 3   Africa Western and Central          AFW  45.272859  43.961196  49.566318
# 4                       Angola          AGO  79.398715  82.568553  77.538003
#
# 0       2003       2004       2005       2006       2007  ...       2013  \
# 0  32.324051  33.045713  37.182001  36.681105  36.934917  ...  46.019737
# 1  34.075988  38.646781  37.432914  32.592505  34.359399  ...  45.296030
# 2        NaN        NaN        NaN        NaN        NaN  ...  21.473801
# 3  50.926078  50.976758  53.313481  42.999541        NaN  ...  35.297194
# 4  81.080360  84.309562  81.213206  71.770144  76.060695  ...  76.943384
#
# ...

# %%
# Step 3: Perform data interpolation on the numeric columns
cleaned_import_tech_df = cleaned_import_tech_df.interpolate()
cleaned_import_tech_df.head(5)
# Out:
# 0                 Country Name Country Code       2000       2001       2002  \
# 0                        Aruba          ABW  77.297780  69.915533  45.738855
# 1  Africa Eastern and Southern          AFE  34.572057  37.172482  34.518234
# 2                  Afghanistan          AFG  39.922458  40.566839  42.042276
# 3   Africa Western and Central          AFW  45.272859  43.961196  49.566318
# 4                       Angola          AGO  79.398715  82.568553  77.538003
#
# 0       2003       2004       2005       2006       2007  ...       2013  \
# 0  32.324051  33.045713  37.182001  36.681105  36.934917  ...  46.019737
# 1  34.075988  38.646781  37.432914  32.592505  34.359399  ...  45.296030
# 2  42.501033  44.811770  45.373197  37.796023  48.259831  ...  21.473801
# 3  50.926078  50.976758  53.313481  42.999541  62.160263  ...  35.297194
# 4  81.080360  84.309562  81.213206  71.770144  76.060695  ...  76.943384
#
# ...

# %%
# Step 1: Melt the DataFrame to transform the years into a separate column
melted_df = cleaned_import_tech_df.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="High Tech Import")

# Step 2: Sort the DataFrame by "Country Name" and "Year" for better organization
melted_df = melted_df.sort_values(by=["Year", "Country Name"])

# Step 3: Reset the index of the DataFrame
melted_df = melted_df.reset_index(drop=True)

# Round all numerical values to two decimal places
melted_df = melted_df.round(2)

# Step 4: Display the modified DataFrame
melted_df.head()
# Out:
#                   Country Name Country Code  Year  High Tech Import
# 0                  Afghanistan          AFG  2000             39.92
# 1  Africa Eastern and Southern          AFE  2000             34.57
# 2   Africa Western and Central          AFW  2000             45.27
# 3                      Albania          ALB  2000             29.35
# 4                      Algeria          DZA  2000             27.38

# %%
# Export the DataFrame to the CSV file
melted_df.to_csv('Cleaned_Data/High_Tech_Import.csv', index=False)
