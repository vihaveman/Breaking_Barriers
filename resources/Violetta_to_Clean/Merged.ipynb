# %%
import pandas as pd
import os

# %%
data = "Cleaned_Data/ATM_Usage.csv"
merged_df = pd.read_csv(data)
merged_df.head(5)
# Out:
#                   Country Name Country Code  Year  ATM Usage
# 0                  Afghanistan          AFG  2010       0.45
# 1  Africa Eastern and Southern          AFE  2010       5.46
# 2   Africa Western and Central          AFW  2010       1.54
# 3                      Albania          ALB  2010      32.94
# 4                      Algeria          DZA  2010       5.33

# %%
# Read in data 
data1 = "Cleaned_Data/GDP.csv"
GDP_df = pd.read_csv(data1)
GDP_df.head(5)
# Out:
#                   Country Name Country Code  Year    GDP
# 0                  Afghanistan          AFG  2010  11.10
# 1  Africa Eastern and Southern          AFE  2010   2.34
# 2   Africa Western and Central          AFW  2010   4.01
# 3                      Albania          ALB  2010   4.22
# 4                      Algeria          DZA  2010   1.69

# %%
# Merge GDP_Df on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, GDP_df[['Country Name', 'Country Code', 'Year', 'GDP']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69

# %%
data2 = "Cleaned_Data/High_Tech_Export.csv"
High_Tech_EX_df = pd.read_csv(data2)
High_Tech_EX_df.head()
# Out:
#                   Country Name Country Code  Year  High Tech Export ($M)
# 0                  Afghanistan          AFG  2010                   0.00
# 1  Africa Eastern and Southern          AFE  2010                1995.96
# 2   Africa Western and Central          AFW  2010                  52.39
# 3                      Albania          ALB  2010                  14.07
# 4                      Algeria          DZA  2010                   5.38

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, High_Tech_EX_df[['Country Name', 'Country Code', 'Year', 'High Tech Export ($M)']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)
# 0                   0.00
# 1                1995.96
# 2                  52.39
# 3                  14.07
# 4                   5.38

# %%
# Read in data 
data3 = "Cleaned_Data/High_Tech_Import.csv"
High_Tech_IM_df= pd.read_csv(data3)
High_Tech_IM_df.head(5)
# Out:
#                   Country Name Country Code  Year  High Tech Import
# 0                  Afghanistan          AFG  2010             18.71
# 1  Africa Eastern and Southern          AFE  2010             39.77
# 2   Africa Western and Central          AFW  2010             40.58
# 3                      Albania          ALB  2010             16.62
# 4                      Algeria          DZA  2010             59.43

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, High_Tech_IM_df[['Country Name', 'Country Code', 'Year', 'High Tech Import']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import
# 0                   0.00             18.71
# 1                1995.96             39.77
# 2                  52.39             40.58
# 3                  14.07             16.62
# 4                   5.38             59.43

# %%
# Read in data 
data4 = "Cleaned_Data/Internet_Subcription.csv"
Internet_df= pd.read_csv(data4)
Internet_df.head(5)
# Out:
#                   Country Name Country Code  Year  \
# 0                  Afghanistan          AFG  2010
# 1  Africa Eastern and Southern          AFE  2010
# 2   Africa Western and Central          AFW  2010
# 3                      Albania          ALB  2010
# 4                      Algeria          DZA  2010
#
#    Internet Subscription Per 100
# 0                           0.01
# 1                           0.20
# 2                           0.11
# 3                           3.62
# 4                           2.51

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Internet_df[['Country Name', 'Country Code', 'Year', 'Internet Subscription Per 100']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51

# %%
# Read in data 
data5 = "Cleaned_Data/Internet_Usage.csv"
Internet_Usage_df = pd.read_csv(data5)
Internet_Usage_df.head(5)
# Out:
#                   Country Name Country Code  Year  Internet Usage Per 100
# 0                  Afghanistan          AFG  2010                    4.00
# 1  Africa Eastern and Southern          AFE  2010                    5.30
# 2   Africa Western and Central          AFW  2010                    7.24
# 3                      Albania          ALB  2010                   45.00
# 4                      Algeria          DZA  2010                   12.50

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Internet_Usage_df[['Country Name', 'Country Code', 'Year', 'Internet Usage Per 100']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100
# 0                    4.00
# 1                    5.30
# 2                    7.24
# ...

# %%
data6 = "Cleaned_Data/IP_Income.csv"
IP_df= pd.read_csv(data6)
IP_df.head(5)
# Out:
#                   Country Name Country Code  Year  IP Income($M)
# 0                  Afghanistan          AFG  2010           0.31
# 1  Africa Eastern and Southern          AFE  2010        1913.59
# 2   Africa Western and Central          AFW  2010         247.50
# 3                      Albania          ALB  2010          12.52
# 4                      Algeria          DZA  2010          10.16

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, IP_df[['Country Name', 'Country Code', 'Year', 'IP Income($M)']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)
# 0                    4.00           0.31
# ...

# %%
data7 = "Cleaned_Data/Labour_Force.csv"
Labour_df = pd.read_csv(data7)
Labour_df.head(5)
# Out:
#                   Country Name Country Code  Year  Labour Force (M)
# 0                  Afghanistan          AFG  2010              6.51
# 1  Africa Eastern and Southern          AFE  2010            204.19
# 2   Africa Western and Central          AFW  2010            124.33
# 3                      Albania          ALB  2010              1.26
# 4                      Algeria          DZA  2010             10.55

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Labour_df[['Country Name', 'Country Code', 'Year', 'Labour Force (M)']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)
# ...

# %%
data8 = "Cleaned_Data/Med_High_Tech_Manufacturing.csv"
Med_High_Tech_Man_DF = pd.read_csv(data8)
Med_High_Tech_Man_DF.head(5)
# Out:
#                   Country Name Country Code  Year  Med_High Tech Manufacturing
# 0                  Afghanistan          AFG  2010                         9.48
# 1  Africa Eastern and Southern          AFE  2010                         0.00
# 2   Africa Western and Central          AFW  2010                         0.00
# 3                      Albania          ALB  2010                         6.56
# 4                      Algeria          DZA  2010                         9.66

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Med_High_Tech_Man_DF[['Country Name', 'Country Code', 'Year', 'Med_High Tech Manufacturing']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)  \
# ...

# %%
data9 = "Cleaned_Data/Mobile Subscription.csv"
Mobile_Sub_df = pd.read_csv(data9)
Mobile_Sub_df.head(5)
# Out:
#                   Country Name Country Code  Year  Mobile Sub Per 100
# 0                  Afghanistan          AFG  2010               36.24
# 1  Africa Eastern and Southern          AFE  2010               38.53
# 2   Africa Western and Central          AFW  2010               52.27
# 3                      Albania          ALB  2010               92.41
# 4                      Algeria          DZA  2010               91.42

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Mobile_Sub_df[['Country Name', 'Country Code', 'Year', 'Mobile Sub Per 100']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)  \
# ...

# %%
data10 = "Cleaned_Data/Personal_Remittance.csv"
Per_Remit_df= pd.read_csv(data10)
Per_Remit_df.head(5)
# Out:
#                   Country Name Country Code  Year  Personal Remittance ($M)
# 0                  Afghanistan          AFG  2010                    140.70
# 1  Africa Eastern and Southern          AFE  2010                   6529.05
# 2   Africa Western and Central          AFW  2010                  21884.17
# 3                      Albania          ALB  2010                   1717.70
# 4                      Algeria          DZA  2010                    150.34

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Per_Remit_df[['Country Name', 'Country Code', 'Year', 'Personal Remittance ($M)']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)  \
# ...

# %%
data12 = "Cleaned_Data/Poverty_Count.csv"
Poverty_df = pd.read_csv(data12)
Poverty_df.head(5)
# Out:
#                   Country Name Country Code  Year  Poverty Count
# 0                  Afghanistan          AFG  2010           0.00
# 1  Africa Eastern and Southern          AFE  2010           0.00
# 2   Africa Western and Central          AFW  2010           0.00
# 3                      Albania          ALB  2010           0.20
# 4                      Algeria          DZA  2010           0.05

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Poverty_df[['Country Name', 'Country Code', 'Year', 'Poverty Count']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)  \
# ...

# %%
data13 = "Cleaned_Data/Stock_Traded.csv"
Stock_df = pd.read_csv(data13)
Stock_df.head(5)
# Out:
#                   Country Name Country Code  Year  Stock Traded $B
# 0                  Afghanistan          AFG  2010             0.00
# 1  Africa Eastern and Southern          AFE  2010             0.00
# 2   Africa Western and Central          AFW  2010             1.35
# 3                      Albania          ALB  2010             0.00
# 4                      Algeria          DZA  2010             0.00

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Stock_df[['Country Name', 'Country Code', 'Year', 'Stock Traded $B']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)  \
# ...

# %%
data14 = "Cleaned_Data/Technical_Cooperation_Grant.csv"
Tech_Grant_df = pd.read_csv(data14)
Tech_Grant_df.head(5)
# Out:
#                   Country Name Country Code  Year  Tech Cooperation Grant($M)
# 0                  Afghanistan          AFG  2010                      957.30
# 1  Africa Eastern and Southern          AFE  2010                        0.00
# 2   Africa Western and Central          AFW  2010                        0.00
# 3                      Albania          ALB  2010                       95.93
# 4                      Algeria          DZA  2010                      191.31

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Tech_Grant_df[['Country Name', 'Country Code', 'Year', 'Tech Cooperation Grant($M)']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)  \
# ...

# %%
data15 = "Cleaned_Data/Unemployment.csv"
Unemployment_df= pd.read_csv(data15)
Unemployment_df.head(5)
# Out:
#                   Country Name Country Code  Year  Unemployment Rate
# 0                  Afghanistan          AFG  2010               8.08
# 1  Africa Eastern and Southern          AFE  2010               6.30
# 2   Africa Western and Central          AFW  2010               4.22
# 3                      Albania          ALB  2010              13.67
# 4                      Algeria          DZA  2010              10.16

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Unemployment_df[['Country Name', 'Country Code', 'Year', 'Unemployment Rate']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#                   Country Name Country Code  Year  ATM Usage    GDP  \
# 0                  Afghanistan          AFG  2010       0.45  11.10
# 1  Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2   Africa Western and Central          AFW  2010       1.54   4.01
# 3                      Albania          ALB  2010      32.94   4.22
# 4                      Algeria          DZA  2010       5.33   1.69
#
#    High Tech Export ($M)  High Tech Import  Internet Subscription Per 100  \
# 0                   0.00             18.71                           0.01
# 1                1995.96             39.77                           0.20
# 2                  52.39             40.58                           0.11
# 3                  14.07             16.62                           3.62
# 4                   5.38             59.43                           2.51
#
#    Internet Usage Per 100  IP Income($M)  Labour Force (M)  \
# ...

# %%
data16 = "Cleaned_Data/Med_High_Tech Export.csv"
Med_High_Tech_EX_df= pd.read_csv(data16)
Med_High_Tech_EX_df.head(5)
# Out:
#                   Country Name Country Code  Year  Med High Tech Export
# 0                  Afghanistan          AFG  2010                  0.38
# 1  Africa Eastern and Southern          AFE  2010                  0.00
# 2   Africa Western and Central          AFW  2010                  0.00
# 3                      Albania          ALB  2010                 15.42
# 4                      Algeria          DZA  2010                  0.46

# %%
# Merge High_Tech DF on the common columns 'Country Name', 'Country Code', and 'Year'
merged_df = pd.merge(merged_df, Med_High_Tech_EX_df[['Country Name', 'Country Code', 'Year', 'Med High Tech Export']], on=['Country Name', 'Country Code', 'Year'], how='left')

# Display the merged DataFrame
merged_df.head(50)
# Out:
#                       Country Name Country Code  Year  ATM Usage    GDP  \
# 0                      Afghanistan          AFG  2010       0.45  11.10
# 1      Africa Eastern and Southern          AFE  2010       5.46   2.34
# 2       Africa Western and Central          AFW  2010       1.54   4.01
# 3                          Albania          ALB  2010      32.94   4.22
# 4                          Algeria          DZA  2010       5.33   1.69
# 5                   American Samoa          ASM  2010       0.00   1.25
# 6                          Andorra          AND  2010       0.00   1.22
# 7                           Angola          AGO  2010       8.34   0.57
# 8              Antigua and Barbuda          ATG  2010      69.03  -9.09
# 9                       Arab World          ARB  2010      16.00   2.24
# 10                       Argentina          ARG  2010      13.86   9.84
# 11                         Armenia          ARM  2010      30.24   2.82
# ...

# %%
print(merged_df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'ATM Usage', 'GDP',
#        'High Tech Export ($M)', 'High Tech Import',
#        'Internet Subscription Per 100', 'Internet Usage Per 100',
#        'IP Income($M)', 'Labour Force (M)', 'Med_High Tech Manufacturing',
#        'Mobile Sub Per 100', 'Personal Remittance ($M)', 'Poverty Count',
#        'Stock Traded $B', 'Tech Cooperation Grant($M)', 'Unemployment Rate',
#        'Med High Tech Export'],
#       dtype='object')

# %%
import pandas as pd

selected_columns = ['Country Name', 'Country Code', 'Year', 'Tech Cooperation Grant($M)']

# Step 1: Copy the DataFrame to avoid modifying the original data
cleaned_df = merged_df.copy()

# Step 2: Convert numeric columns (excluding 'Tech Cooperation Grant($M)') to numeric data type
numeric_columns = [column for column in cleaned_df.columns if column not in selected_columns]
cleaned_df[numeric_columns] = cleaned_df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Step 3: Replace '0.00' with NaN for numeric columns (excluding 'Tech Cooperation Grant($M)')
cleaned_df[numeric_columns] = cleaned_df[numeric_columns].replace(0.00, pd.NA)

# Step 4: Print the cleaned DataFrame
cleaned_df.head()
# Out:
#                   Country Name Country Code  Year ATM Usage   GDP  \
# 0                  Afghanistan          AFG  2010      0.45  11.1
# 1  Africa Eastern and Southern          AFE  2010      5.46  2.34
# 2   Africa Western and Central          AFW  2010      1.54  4.01
# 3                      Albania          ALB  2010     32.94  4.22
# 4                      Algeria          DZA  2010      5.33  1.69
#
#   High Tech Export ($M) High Tech Import Internet Subscription Per 100  \
# 0                  <NA>            18.71                          0.01
# 1               1995.96            39.77                           0.2
# 2                 52.39            40.58                          0.11
# 3                 14.07            16.62                          3.62
# 4                  5.38            59.43                          2.51
#
#   Internet Usage Per 100 IP Income($M) Labour Force (M)  \
# 0                    4.0          0.31             6.51
# ...

# %%
cleaned_df = cleaned_df.dropna()
cleaned_df.head(5)
# Out:
#    Country Name Country Code  Year ATM Usage   GDP High Tech Export ($M)  \
# 10    Argentina          ARG  2010     13.86  9.84               1686.22
# 13    Australia          AUS  2010    154.32  0.63                4554.4
# 14      Austria          AUT  2010    112.34  1.59              15801.88
# 18   Bangladesh          BGD  2010      1.29  4.37                 37.56
# 21      Belgium          BEL  2010     87.37  1.93              18056.97
#
#    High Tech Import Internet Subscription Per 100 Internet Usage Per 100  \
# 10            33.65                           9.8                   45.0
# 13            25.79                         25.02                   76.0
# 14            35.94                         24.52                  75.17
# 18             19.5                          0.28                    3.7
# 21            41.87                         31.01                   75.0
#
#    IP Income($M) Labour Force (M) Med_High Tech Manufacturing  \
# ...

# %%
cleaned_df.to_csv('Cleaned_Data/World_Bank.csv', index=False)
