# %%
import pandas as pd
import os

# %%
internet_usage = "Individuals_Internet_usage.csv"
internet_usage_df = pd.read_csv(internet_usage, sep="\t")
internet_usage_df
# Out:
#            Data Source,"World Development Indicators",
# 0                      Last Updated Date,"2023-06-29",
# 1    Country Name,"Country Code","Indicator Name","...
# 2    Aruba,"ABW","Individuals using the Internet (%...
# 3    Africa Eastern and Southern,"AFE","Individuals...
# 4    Afghanistan,"AFG","Individuals using the Inter...
# ..                                                 ...
# 263  Kosovo,"XKX","Individuals using the Internet (...
# 264  Yemen, Rep.,"YEM","Individuals using the Inter...
# 265  South Africa,"ZAF","Individuals using the Inte...
# 266  Zambia,"ZMB","Individuals using the Internet (...
# 267  Zimbabwe,"ZWE","Individuals using the Internet...
#
# [268 rows x 1 columns]

# %%
list(internet_usage_df)
# Out:
# ['Data Source,"World Development Indicators",']

# %%
# Get the contents of row 2
row_2_data = internet_usage_df.iloc[1]
# Convert row 2 data to a list
columns = row_2_data.tolist()
columns
# Out:
# ['Country Name,"Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",']

# %%
# Split the column on the comma and place in a list.
for column in columns:
    column_names = column.split(",")
print(len(column_names))
# Out:
# 68

# %%
split_data = internet_usage_df['Data Source,"World Development Indicators",'].str.split(',', n=68, expand=True)

# Create a new DataFrame to store the cleaned data with appropriate column names
cleaned_internet_usage_df= pd.DataFrame(
    {
        'Country Name': split_data[0],
        'Country Code': split_data[1],
        'Indicator Name': split_data[2],
        'Indicator Code': split_data[3],
    }
)

# Concatenate the remaining columns from split_data to cleaned_atm_df
cleaned_internet_usage_df = pd.concat([cleaned_internet_usage_df, split_data.iloc[:, 4:]], axis=1)
cleaned_internet_usage_df = cleaned_internet_usage_df.drop(index=0).reset_index(drop=True)
# Display the cleaned DataFrame
cleaned_internet_usage_df.head(5)
# Out:
#                   Country Name    Country Code  \
# 0                 Country Name  "Country Code"
# 1                        Aruba           "ABW"
# 2  Africa Eastern and Southern           "AFE"
# 3                  Afghanistan           "AFG"
# 4   Africa Western and Central           "AFW"
#
#                                       Indicator Name    Indicator Code  \
# 0                                   "Indicator Name"  "Indicator Code"
# 1  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"
# 2  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"
# 3  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"
# 4  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"
#
#         4       5       6       7       8       9  ...                  59  \
# 0  "1960"  "1961"  "1962"  "1963"  "1964"  "1965"  ...              "2015"
# 1      ""      ""      ""      ""      ""      ""  ...       "88.66122693"
# ...

# %%
# Define a function to remove double quotes from each cell
def remove_quotes(cell_value):
    if cell_value is not None:
        return cell_value.replace('"', '')
    else:
        return cell_value

# Use applymap() to remove double quotes from the entire DataFrame
cleaned_internet_usage_df_final = cleaned_internet_usage_df.applymap(remove_quotes)

# Display the first five rows of the cleaned DataFrame
cleaned_internet_usage_df_final.head(5)
# Out:
#                   Country Name  Country Code  \
# 0                 Country Name  Country Code
# 1                        Aruba           ABW
# 2  Africa Eastern and Southern           AFE
# 3                  Afghanistan           AFG
# 4   Africa Western and Central           AFW
#
#                                      Indicator Name  Indicator Code     4  \
# 0                                    Indicator Name  Indicator Code  1960
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS
#
#       5     6     7     8     9  ...                59                60  \
# 0  1961  1962  1963  1964  1965  ...              2015              2016
# 1                                ...       88.66122693       93.54245387
# ...

# %%
# Assign row 0 as column names
cleaned_internet_usage_df.columns = cleaned_internet_usage_df.iloc[0]
cleaned_internet_usage_df.columns = cleaned_internet_usage_df.columns.str.replace('"', '')  # Remove any quotation marks from column names

# Drop row 0 from the DataFrame
cleaned_internet_usage_df = cleaned_internet_usage_df.drop(index=0).reset_index(drop=True)

# Display the cleaned DataFrame
cleaned_internet_usage_df.sample(5)
# Out:
# 0                 Country Name Country Code  \
# 259                      World        "WLD"
# 131                    Liberia        "LBR"
# 205               Saudi Arabia        "SAU"
# 225  Sint Maarten (Dutch part)        "SXM"
# 16                     Burundi        "BDI"
#
# 0                                       Indicator Name    Indicator Code 1960  \
# 259  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"   ""
# 131  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"   ""
# 205  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"   ""
# 225  "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"   ""
# 16   "Individuals using the Internet (% of populati...  "IT.NET.USER.ZS"  "0"
#
# 0   1961 1962 1963 1964 1965  ...                2015                2016  \
# 259   ""   ""   ""   ""   ""  ...  "40.2700586394911"  "43.2159445206951"
# 131   ""   ""   ""   ""   ""  ...                "10"              "15.7"
# ...

# %%
# Define a function to remove double quotes from each cell
def remove_quotes(cell_value):
    if cell_value is not None:
        return cell_value.replace('"', '')
    else:
        return cell_value

# Use applymap() to remove double quotes from the entire DataFrame
cleaned_internet_usage_df_final = cleaned_internet_usage_df.applymap(remove_quotes)

# Display the first five rows of the cleaned DataFrame
cleaned_internet_usage_df_final.head(5)
# Out:
# 0                 Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
# 0                                    Indicator Name  Indicator Code 1960 1961  \
# 0  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS
#
# 0 1962 1963 1964 1965  ...              2015              2016  \
# 0                      ...       88.66122693       93.54245387
# 1                      ...  14.4858491534531   15.753329822739
# 2                      ...              8.26                11
# ...

# %%
# Convert columns to float data type
for column in cleaned_internet_usage_df_final.columns[55:66]:
    cleaned_internet_usage_df_final[column] = pd.to_numeric(cleaned_internet_usage_df_final[column], errors='coerce')

# Display the DataFrame with the specified columns converted to float
cleaned_internet_usage_df_final.head(5)
# Out:
# 0                 Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
# 0                                    Indicator Name  Indicator Code 1960 1961  \
# 0  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS
#
# 0 1962 1963 1964 1965  ...       2015       2016       2017       2018  \
# 0                      ...  88.661227  93.542454  97.170000        NaN
# 1                      ...  14.485849  15.753330  17.310987  20.063024
# ...

# %%
# # Convert columns to float data type
# for column in cleaned_internet_usage_df_final.columns[60:67]:
#     cleaned_internet_usage_df_final[column] = pd.to_numeric(cleaned_internet_usage_df_final[column], errors='coerce')

# # Fill non-finite values (NaN) with a default value (e.g., 0)
# cleaned_internet_usage_df_final.fillna(0, inplace=True)

# # Convert the specified columns from float to integer data type
# cleaned_internet_usage_df_final.iloc[:, 60:67] = cleaned_internet_usage_df_final.iloc[:, 60:67].astype(int)

# # Display the DataFrame with the specified columns converted to integer
# cleaned_internet_usage_df_final.head(5)

# %%
cleaned_internet_usage_df_final.dtypes
# Out:
# 0
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960               object
#                    ...
# 2020              float64
# 2021              float64
# 2022               object
#                    object
# None               object
# Length: 69, dtype: object

# %%
# Slice the DataFrame from column index 55 to 65 (inclusive)
selected_columns = cleaned_internet_usage_df_final.iloc[:, 55:66]
# Get the column names of the selected columns
column_names = selected_columns.columns.tolist()
# Print the column names
print(column_names)
# Out:
# ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
import numpy as np

# Replace 0 with NaN in the DataFrame
cleaned_internet_usage_df_final.replace(0, np.nan, inplace=True)

# Calculate the latest value for each row in columns , ignoring NaN values and considering the last non-NaN value
if cleaned_internet_usage_df_final.shape[1] >= 66:
    latest = cleaned_internet_usage_df_final.iloc[:, 55:66].apply(lambda row: row.dropna().iloc[-1] if not row.dropna().empty else np.nan, axis=1)
else:
    latest = cleaned_internet_usage_df_final.iloc[:, 55:].apply(lambda row: row.dropna().iloc[-1] if not row.dropna().empty else np.nan, axis=1)

# Add the latest values as a new column named "individuals_%_use_int" to the DataFrame
cleaned_internet_usage_df_final['individuals_%_use_int'] = latest

# Display the DataFrame to verify the changes
cleaned_internet_usage_df_final.sample(50)
# Out:
# 0                                         Country Name Country Code  \
# 127                                             Kuwait          KWT
# 253                     St. Vincent and the Grenadines          VCT
# 54                                             Czechia          CZE
# 134                          Latin America & Caribbean          LCN
# 81                                      United Kingdom          GBR
# 160                                            Myanmar          MMR
# 246                                           Tanzania          TZA
# 188                                              Palau          PLW
# 209                                    Solomon Islands          SLB
# 85                                              Guinea          GIN
# 139                                Lower middle income          LMC
# 167                                          Mauritius          MUS
# 238  Middle East & North Africa (IDA & IBRD countries)          TMN
# ...

# %%
intusage_machine_df=cleaned_internet_usage_df_final[['Country Name','individuals_%_use_int']]
intusage_machine_df.sample(50)
# Out:
# 0                                   Country Name  individuals_%_use_int
# 63                           East Asia & Pacific              72.234987
# 205                                 Saudi Arabia             100.000000
# 54                                       Czechia              82.670624
# 228                     Turks and Caicos Islands                    NaN
# 10                                       Armenia              78.612258
# 70                                         Spain              93.900000
# 187                                  Philippines              52.675738
# 137                                Liechtenstein              95.569376
# 189                             Papua New Guinea              32.054163
# 244                                      Turkiye              81.410000
# 265                                     Zimbabwe              34.813971
# 112                                         Iran              75.569866
# ...

# %%
# Create the "Output_Jibek" directory if it doesn't exist
output_directory = "../Output_Jibek"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)
# Save the cleaned DataFrame to a CSV file in the specified directory
intusage_machine_df.to_csv(os.path.join(output_directory, 'intusage_machine_df'), index=False)
